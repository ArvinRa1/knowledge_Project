# %%
from sympy import *
import random
import sys
import numpy as np
import itertools
from scipy.stats import expon

# %%
# Preprocessing level for recognizing clauses in formulas of CNForm and literals as variables
input = " (~a) & (b | a) & (~c | ~b) & (~c) & (~c | d) & (~e | ~a )  "
def preprocess(input):
  """ 
   The output is a tuple with three returns inside the first one a list of literals, the second one the tuple of cluases and
   third one is the formula itself sympified
  """
  input = sympify(input, evaluate=False)
  literals = input.atoms()
  clause = []
  clause.append(clauses(input))
  return literals, clause[0], input 
## for CNFs only
def clauses(input): 
  input = sympify(input, evaluate=False)
  if not isinstance(input, And):
      return input,
  return sympify(input.args)
#print(clauses(input))
#print(type(clauses(input)))
#print(preprocess(input)[0])
#print(type(preprocess(input)[1]))

# %%
# Preprocessing level for recognizing clauses in formulas of CNForm and literals as variables
input = " (~a) & (b | a) & (~c | ~b) & (~c) & (~c | d) & (~e | ~a )  "
class Preprocess():
    """ 
    The output is a tuple with three returns inside the first one a list of literals, the second one the tuple of clauses and
    third one is the formula itself sympified
    """
    # for CNFs only
    def __init__(self, input):
        self.input = sympify(input, evaluate=False)
        self.literals = self.input.atoms() 
        self.clauses = set(self.input.args)

print(type(Preprocess(input).clauses))
print(type(Preprocess(input).literals))
print(type(Preprocess(input).input))
# Out:
# <class 'set'>
# <class 'set'>
# And

# %%
def decision(probability = 0.5):
    return random.random() < probability

# %%
class SampleSat():
    Label = "SampleSat Algorithm"
    def __init__(self, input):
        self.input = sympify(input, evaluate=False)
        self.literals = input.atoms() 
        self.cluses = sympify(self.input.args) 
        self.falseclauses = set()
        self.trueCluses = set()
        self.dictionary = {}

# %%
#"  (~a | b) & (~b | ~c) & (~c) & (~a) "

def ChooseVar(sT, clF, dict1):
  clF = clF
  cho1 = random.choice(list(clF))
  sT = sT
  dict2 = dict1
  sT1 = set()
  dict3 = dict2.copy()
  dict4 = dict2.copy()
  bvl = []
  ##### Break value calculation
  for lit in cho1.atoms():
    print("dict2: ",dict2)
    dict2[lit] = not dict2[lit]
    vars = list(preprocess(input)[0])
    clauses1 = clauses(sT)
    dict1 = dict2
    sat = []
    clauses1 = set(clauses1)
    clF =  set()     # The set that we put the clauses that are still false inside
    clT = clauses1.copy()
    vltf = str()
    for clause in clauses1:   
      temp = clause
      #print("clause before: ", clause)
      for key in dict1.keys():
        clT = set(clT)
        if key in clause.atoms():
          clause = clause.subs({key: dict1[key]})
          #print("clause after: ", clause)              # Adding false clauses to the set
        if not clause:
          clF.add(temp)
        if temp in clF:
          clT.remove(temp)
    #prw1 = PRW(sT, dict2)
    #sT1 = prw1[1]
    #sat = prw1[4]
    #print("sat: ", sat)
    #print("sT1: ",sT1)
    bv = len(sT1) - len(clT)
    bvl.append(max(0, bv))
    dict3.update({lit: [not dict2[lit], max(0, bv)]})
  #####
  #print("dict3",dict3)
  #print("bvl",bvl)
  # chooseVar 
  vltflst = []      # value to flip list 
  probability= 0.5  ##### q probability  
  for key, value in dict3.items():
    if not type(value) == bool :
      if value[1] == 0 :          # if break value equal 0 chose the variable
        vltflst.extend([key, value[1]])
        print("vltflst: ", vltflst)
        vltf = key              # value to flip 
    else :
      #print("we shouldn't print this")
      if decision(probability):               # with probability of q chose randomly between the vars in cho1
        #print("we shouldn't print this1")
        vltf = random.sample(cho1.atoms(), 1)[0]
      else:                                   # with probability 1-q chose the min of break values in among the literals
        try:
          vltf = vltflst[vltflst.index(min(vltflst))-1]      
          #print("we shouldn't print this2")
        except ValueError:
          pass
        except TypeError:
          pass
  return vltf

# %%
def Metropolis(sT, dict1, T = 1):
  t = T
  sT = sT
  vars = list(preprocess(input)[0])
  dict1 = dict1
  costl = []
  #if len(dict1) == 0:
  for atom in vars:   # Randomly initilizing the vars to T and F
    dict1[atom] = random.choice([True, False])
      #dict1[atom]= True  # for testing
  dict2 = dict1.copy()
  dict3 = dict2.copy()
  #==============================================================================================================
  ##### Cost calculation
  for lit in vars:
    #print("dict2: ",dict2)
    dict2[lit] = not dict2[lit]
    vars = list(preprocess(input)[0])
    clauses1 = clauses(sT)
    dict1 = dict2
    sat = []
    clauses1 = set(clauses1)
    clF =  set()     # The set that we put the clauses that are still false inside
    clT = clauses1.copy()
    vltf = str()
    clauses1 = clauses(input)
    clauses1 = set(clauses1)
    dict1 = dict2.copy()
    clf =  set()     
    clt = clauses1.copy()
    for clause in clauses1:   
      temp = clause
      #print("clause before: ", clause)
      for key in dict1.keys():
        clt = set(clt)
        if key in clause.atoms():
          clause = clause.subs({key: dict1[key]})
            # Adding false clauses to the set
        if not clause:
          clf.add(temp)
      if temp in clf:
        clt.remove(temp)
    sT1 = clt
    print("sT1: ", sT1)
    bv = len(sT) - len(sT1)
    costl.append(bv)
    print("costl: ", costl)
    dict3.update({lit: [not dict2[lit], bv]}) 
  print("dict3: ",dict3)
  ######==========================================================
  vltf = random.choice(vars)
  costVltf = dict3[vltf][1]
  print("costVltf: ", costVltf)
  ex = expon.pdf(costVltf) / t
  print("expon.pdf(costVltf) / t: ", ex)
  rand = random.random()
  print("rand: ", rand)
  if costVltf <= 0:
    return [vltf, True]
  elif rand  < ex:
    return [vltf , True]
  else:
    return [vltf , not vltf]
prw = PRW(input)
Metropolis(prw[1], dict1=prw[3] )
# Out:
# clauses1:  (~a, ~c, a | b, d | ~c, ~a | ~e, ~b | ~c)
# i0 :  0
# dict1:  {b: True, c: False, d: True, a: False, e: False}
# clF:  set()
# clT:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# The formula is satisfied
# sT1:  {~a | ~e, a | b, d | ~c}
# costl:  [3]
# sT1:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# costl:  [3, 1]
# sT1:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# costl:  [3, 1, 1]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [3, 1, 1, 0]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [3, 1, 1, 0, 0]
# dict3:  {b: [False, 3], c: [True, 1], d: [True, 1], a: [True, 0], e: [False, 0]}
# costVltf:  1
# expon.pdf(costVltf) / t:  0.36787944117144233
# rand:  0.30053492952445804
# [c, True]

# %%
def PRW(input, dt = {}, P = 0.5, T = 1):  # Returns the set of false clauses, set of truth clauses, the clause chosen at random from False cluases
                  # Also returns formula is satisfied when there is no false clauses and the dict of assigned values to vars
  p = P
  t = T
  vars = list(preprocess(input)[0])
  clauses1 = clauses(input)
  dict1 = dt
  isat = 0
  sat = []
  if True:#len(dict1) == 0:
    for atom in vars:   # Randomly initilizing the vars to T and F
      dict1[atom] = random.choice([True, False])
      #dict1[atom]= True  # for testing
  print("clauses1: ",clauses1)
  clauses1 = list(clauses1)
  clF =  set()     # The set that we put the clauses that are still false inside
  clT = clauses1.copy()
  vltf = str()
  for i0 in range(0,1000):
    if len(clF) != 0:
      if vltf[0] in dict1 & vltf[1]:
        dict1[vltf[0]] = not dict1[vltf[0]]
    for clause in clauses1:   
      temp = clause
      #print("clause before: ", clause)
      for key in dict1.keys():
        clT = set(clT)
        if key in clause.atoms():
          clause = clause.subs({key: dict1[key]})
          #print("clause after: ", clause)              # Adding false clauses to the set
        if not clause:
          clF.add(temp)
      if temp in clF:
        clT.remove(temp)
    print("clF: ", clF)
    print("clT: ", clT)
    if len(clF) == 0:
      sat.append(dict1)
      #print("dict1: ", dict1)
      print("The formula is satisfied") 
      break
    if len(clF) != 0:
      if decision(p):
        vltf = ChooseVar(clT, clF, dict1)
      else: 
        vltf = Metropolis(clT, dict1 , T = t)
      clF = set()      # The set that we put the clauses that are still false inside
      clT = clauses1.copy()
  return clF, clT, 0, dict1, sat
     


#prw = PRW(input)
#print("PRW: ",prw)
#print("prw[1] :",prw[1])
#print(PRW(prw[1],prw[3]))
# Out:
# clauses1:  (~a, ~c, a | b, d | ~c, ~a | ~e, ~b | ~c)
# i0 :  0
# dict1:  {b: True, c: True, d: False, a: True, e: False}
# clF:  {~c, ~b | ~c, d | ~c, ~a}
# clT:  {~a | ~e, a | b}
# sT1:  {~a | ~e, a | b, d | ~c}
# costl:  [-1]
# sT1:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# costl:  [-1, -3]
# sT1:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# costl:  [-1, -3, -3]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [-1, -3, -3, -4]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [-1, -3, -3, -4, -4]
# dict3:  {b: [False, -1], c: [True, -3], d: [True, -3], a: [True, -4], e: [False, -4]}
# costVltf:  -3
# expon.pdf(costVltf) / t:  0.0
# rand:  0.22648947186232704
# i0 :  1
# dict1:  {b: False, c: True, d: True, a: True, e: False}
# clF:  {~c, ~a}
# clT:  {~b | ~c, ~a | ~e, d | ~c, a | b}
# sT1:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# costl:  [-1]
# sT1:  {~b | ~c, ~a | ~e, ~a}
# costl:  [-1, 1]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, ~a}
# costl:  [-1, 1, 0]
# sT1:  {~b | ~c, a | b, d | ~c}
# costl:  [-1, 1, 0, 1]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b}
# costl:  [-1, 1, 0, 1, 0]
# dict3:  {b: [True, -1], c: [False, 1], d: [False, 0], a: [False, 1], e: [True, 0]}
# costVltf:  1
# expon.pdf(costVltf) / t:  0.36787944117144233
# rand:  0.1095868686292426
# i0 :  2
# dict1:  {b: True, c: False, d: False, a: False, e: True}
# clF:  set()
# clT:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# The formula is satisfied
# PRW:  (set(), {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}, 0, {b: True, c: False, d: False, a: False, e: True}, [{b: True, c: False, d: False, a: False, e: True}])

# %%
def unitprop(input, literal):
  vars = list(preprocess(input)[0])
  output = []
  for var in vars:
    if literal != var:
      output.append(var)  
  print("output:", output)
  return output
vars = list(preprocess(input)[0])
print("vars: ", vars)
#print("lit: ", lit)
#unitprop(input, lit)
# Out:
# vars:  [b, c, d, a, e]

# %%
## ApproxCount Algorithm
k = 5
nsat = []
nsatSet = []
inputSet = Preprocess(input)
#==============
# constructiong solution space of
for i in range(0,20):   # 
  anw = PRW(input)[3]
  anw1 = anw.copy()
  print("anw: ", anw1)
  #anw = prw[4]
  nsat.append(anw1)
  print("nsat: ", nsat)
  ##  Dropping duplicates in the nsat list 
  if anw1 not in nsatSet:   
    nsatSet.append(anw1)
  if len(nsatSet) == k:
    break 

print("nsat: ", nsat)
print("nsatSet: ", nsatSet)
k = len(nsatSet)
mx = []
pickvarF = list(inputSet.literals)
print("pickvarF: ", pickvarF)

for x in pickvarF:
    print("x: ", x)
    nf = 0.0
    nt = 0.0
    for sat in nsatSet:
        print("sat: ", sat)
        dic = sat
        x1 = dic[x]
        print("x1: ", x1)
        if x1 == True:
            nt += 1.0  
        if x1 == False:
            nf += 1.0 
    if nt > nf:
        ## unitprop F
        #pickvarF = unitprop(pickvarF, x)
        print("nt: ", nt)
        temp = k/nt
        mx.append(temp)
        print("mxt:", mx)
    else:
        ### unitprop F
        #pickvarF = unitprop(pickvarF, x)
        temp = k/nf
        mx.append(temp)
        print("mxf:", mx)

result = np.prod(mx) 
print("result:", result)
# Out:
# clauses1:  (~a, ~c, a | b, d | ~c, ~a | ~e, ~b | ~c)
# i0 :  0
# dict1:  {b: False, c: True, d: True, a: True, e: True}
# clF:  {~c, ~a | ~e, ~a}
# clT:  {~b | ~c, a | b, d | ~c}
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [-3]
# sT1:  {~a, ~a | ~e, d | ~c, a | b}
# costl:  [-3, -1]
# sT1:  {~a, ~a | ~e, a | b}
# costl:  [-3, -1, 0]
# sT1:  {a | b}
# costl:  [-3, -1, 0, 2]
# sT1:  {~a | ~e, a | b}
# costl:  [-3, -1, 0, 2, 1]
# dict3:  {b: [False, -3], c: [False, -1], d: [True, 0], a: [False, 2], e: [True, 1]}
# costVltf:  -3
# expon.pdf(costVltf) / t:  0.0
# rand:  0.7357285805091848
# i0 :  1
# dict1:  {b: False, c: False, d: True, a: False, e: True}
# clF:  {a | b}
# clT:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# dict2:  {b: False, c: False, d: True, a: False, e: True}
# dict2:  {b: False, c: False, d: True, a: True, e: True}
# vltflst:  [b, 0]
# vltflst:  [b, 0, a, 0]
# i0 :  2
# dict1:  {b: True, c: False, d: True, a: True, e: True}
# clF:  {~a | ~e, ~a}
# clT:  {~b | ~c, ~c, d | ~c, a | b}
# dict2:  {b: True, c: False, d: True, a: True, e: True}
# vltflst:  [a, 0]
# i0 :  3
# dict1:  {b: True, c: False, d: True, a: False, e: True}
# clF:  set()
# clT:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# The formula is satisfied
# anw:  {b: True, c: False, d: True, a: False, e: True}
# nsat:  [{b: True, c: False, d: True, a: False, e: True}]
# clauses1:  (~a, ~c, a | b, d | ~c, ~a | ~e, ~b | ~c)
# i0 :  0
# dict1:  {b: False, c: True, d: True, a: True, e: True}
# clF:  {~c, ~a | ~e, ~a}
# clT:  {~b | ~c, a | b, d | ~c}
# sT1:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# costl:  [-2]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, ~a}
# costl:  [-2, -1]
# sT1:  {~b | ~c, ~a | ~e, ~a}
# costl:  [-2, -1, 0]
# sT1:  {~b | ~c, a | b}
# costl:  [-2, -1, 0, 1]
# sT1:  {~b | ~c, ~a | ~e, a | b}
# costl:  [-2, -1, 0, 1, 0]
# dict3:  {b: [True, -2], c: [False, -1], d: [True, 0], a: [False, 1], e: [True, 0]}
# costVltf:  -2
# expon.pdf(costVltf) / t:  0.0
# rand:  0.1043212301678158
# i0 :  1
# dict1:  {b: True, c: False, d: True, a: False, e: True}
# clF:  set()
# clT:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# The formula is satisfied
# anw:  {b: True, c: False, d: True, a: False, e: True}
# nsat:  [{b: True, c: False, d: True, a: False, e: True}, {b: True, c: False, d: True, a: False, e: True}]
# clauses1:  (~a, ~c, a | b, d | ~c, ~a | ~e, ~b | ~c)
# i0 :  0
# dict1:  {b: False, c: True, d: False, a: True, e: False}
# clF:  {~c, d | ~c, ~a}
# clT:  {~b | ~c, ~a | ~e, a | b}
# dict2:  {b: False, c: True, d: False, a: True, e: False}
# vltflst:  [c, 0]
# i0 :  1
# dict1:  {b: False, c: False, d: False, a: True, e: False}
# clF:  {~a}
# clT:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# dict2:  {b: False, c: False, d: False, a: True, e: False}
# vltflst:  [a, 0]
# i0 :  2
# dict1:  {b: False, c: False, d: False, a: False, e: False}
# clF:  {a | b}
# clT:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# dict2:  {b: False, c: False, d: False, a: False, e: False}
# dict2:  {b: False, c: False, d: False, a: True, e: False}
# vltflst:  [b, 0]
# vltflst:  [b, 0, a, 0]
# i0 :  3
# dict1:  {b: True, c: False, d: False, a: True, e: False}
# clF:  {~a}
# clT:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# dict2:  {b: True, c: False, d: False, a: True, e: False}
# vltflst:  [a, 0]
# i0 :  4
# dict1:  {b: True, c: False, d: False, a: False, e: False}
# clF:  set()
# clT:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# The formula is satisfied
# anw:  {b: True, c: False, d: False, a: False, e: False}
# nsat:  [{b: True, c: False, d: True, a: False, e: True}, {b: True, c: False, d: True, a: False, e: True}, {b: True, c: False, d: False, a: False, e: False}]
# clauses1:  (~a, ~c, a | b, d | ~c, ~a | ~e, ~b | ~c)
# i0 :  0
# dict1:  {b: True, c: True, d: False, a: True, e: True}
# clF:  {~b | ~c, ~c, ~a, ~a | ~e, d | ~c}
# clT:  {a | b}
# sT1:  {~a, ~a | ~e, a | b}
# costl:  [-2]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [-2, -5]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [-2, -5, -5]
# sT1:  {~b | ~c, ~c, d | ~c, a | b}
# costl:  [-2, -5, -5, -3]
# sT1:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# costl:  [-2, -5, -5, -3, -4]
# dict3:  {b: [False, -2], c: [True, -5], d: [False, -5], a: [False, -3], e: [True, -4]}
# costVltf:  -2
# expon.pdf(costVltf) / t:  0.0
# rand:  0.8926824440694082
# i0 :  1
# dict1:  {b: False, c: True, d: False, a: False, e: True}
# clF:  {~c, d | ~c, a | b}
# clT:  {~b | ~c, ~a | ~e, ~a}
# dict2:  {b: False, c: True, d: False, a: False, e: True}
# dict2:  {b: False, c: False, d: False, a: False, e: True}
# vltflst:  [c, 0]
# vltflst:  [c, 0, d, 0]
# i0 :  2
# dict1:  {b: False, c: False, d: True, a: False, e: True}
# clF:  {a | b}
# clT:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# sT1:  {~b | ~c, ~a | ~e, ~a}
# costl:  [2]
# sT1:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# costl:  [2, 0]
# sT1:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# costl:  [2, 0, 0]
# sT1:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# costl:  [2, 0, 0, 0]
# sT1:  {~b | ~c, ~c, d | ~c, a | b}
# costl:  [2, 0, 0, 0, 1]
# dict3:  {b: [True, 2], c: [True, 0], d: [False, 0], a: [False, 0], e: [False, 1]}
# costVltf:  0
# expon.pdf(costVltf) / t:  1.0
# rand:  0.43910698569204576
# i0 :  3
# dict1:  {b: True, c: True, d: False, a: False, e: False}
# clF:  {~c, ~b | ~c, d | ~c}
# clT:  {~a, ~a | ~e, a | b}
# dict2:  {b: True, c: True, d: False, a: False, e: False}
# vltflst:  [c, 0]
# i0 :  4
# dict1:  {b: True, c: False, d: False, a: False, e: False}
# clF:  set()
# clT:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# The formula is satisfied
# anw:  {b: True, c: False, d: False, a: False, e: False}
# nsat:  [{b: True, c: False, d: True, a: False, e: True}, {b: True, c: False, d: True, a: False, e: True}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}]
# clauses1:  (~a, ~c, a | b, d | ~c, ~a | ~e, ~b | ~c)
# i0 :  0
# dict1:  {b: False, c: False, d: True, a: True, e: True}
# clF:  {~a | ~e, ~a}
# clT:  {~b | ~c, ~c, d | ~c, a | b}
# sT1:  {~a | ~e, a | b, d | ~c}
# costl:  [1]
# sT1:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# costl:  [1, -1]
# sT1:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# costl:  [1, -1, -1]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [1, -1, -1, -2]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [1, -1, -1, -2, -2]
# dict3:  {b: [False, 1], c: [True, -1], d: [True, -1], a: [True, -2], e: [False, -2]}
# costVltf:  -2
# expon.pdf(costVltf) / t:  0.0
# rand:  0.3520592954361548
# i0 :  1
# dict1:  {b: False, c: True, d: True, a: True, e: False}
# clF:  {~c, ~a}
# clT:  {~b | ~c, ~a | ~e, d | ~c, a | b}
# dict2:  {b: False, c: True, d: True, a: True, e: False}
# vltflst:  [a, 0]
# i0 :  2
# dict1:  {b: False, c: True, d: True, a: False, e: False}
# clF:  {~c, a | b}
# clT:  {~b | ~c, ~a | ~e, d | ~c, ~a}
# dict2:  {b: False, c: True, d: True, a: False, e: False}
# dict2:  {b: False, c: True, d: True, a: True, e: False}
# vltflst:  [b, 0]
# vltflst:  [b, 0, a, 0]
# i0 :  3
# dict1:  {b: True, c: True, d: True, a: True, e: False}
# clF:  {~c, ~b | ~c, ~a}
# clT:  {~a | ~e, d | ~c, a | b}
# sT1:  {~b | ~c, ~c, d | ~c, a | b}
# costl:  [-1]
# sT1:  {a | b}
# costl:  [-1, 2]
# sT1:  {d | ~c, a | b}
# costl:  [-1, 2, 1]
# sT1:  {~a, ~a | ~e, d | ~c, a | b}
# costl:  [-1, 2, 1, -1]
# sT1:  {~a, ~a | ~e, d | ~c, a | b}
# costl:  [-1, 2, 1, -1, -1]
# dict3:  {b: [False, -1], c: [False, 2], d: [False, 1], a: [True, -1], e: [True, -1]}
# costVltf:  -1
# expon.pdf(costVltf) / t:  0.0
# rand:  0.8315178573489564
# i0 :  4
# dict1:  {b: False, c: False, d: False, a: True, e: True}
# clF:  {~a | ~e, ~a}
# clT:  {~b | ~c, ~c, d | ~c, a | b}
# sT1:  {a | b}
# costl:  [3]
# sT1:  {~b | ~c, ~c, d | ~c, a | b}
# costl:  [3, 0]
# sT1:  {~b | ~c, ~c, d | ~c, a | b}
# costl:  [3, 0, 0]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [3, 0, 0, -2]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [3, 0, 0, -2, -2]
# dict3:  {b: [False, 3], c: [True, 0], d: [False, 0], a: [True, -2], e: [True, -2]}
# costVltf:  0
# expon.pdf(costVltf) / t:  1.0
# rand:  0.1195910287178914
# i0 :  5
# dict1:  {b: False, c: True, d: False, a: True, e: True}
# clF:  {~c, ~a | ~e, d | ~c, ~a}
# clT:  {~b | ~c, a | b}
# dict2:  {b: False, c: True, d: False, a: True, e: True}
# dict2:  {b: False, c: False, d: False, a: True, e: True}
# vltflst:  [c, 0]
# vltflst:  [c, 0, d, 0]
# i0 :  6
# dict1:  {b: False, c: False, d: True, a: True, e: True}
# clF:  {~a | ~e, ~a}
# clT:  {~b | ~c, ~c, d | ~c, a | b}
# dict2:  {b: False, c: False, d: True, a: True, e: True}
# vltflst:  [a, 0]
# i0 :  7
# dict1:  {b: False, c: False, d: True, a: False, e: True}
# clF:  {a | b}
# clT:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# sT1:  {~b | ~c, ~c, d | ~c, a | b}
# costl:  [1]
# sT1:  {~b | ~c, a | b}
# costl:  [1, 3]
# sT1:  {~b | ~c, a | b, d | ~c}
# costl:  [1, 3, 2]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, ~a}
# costl:  [1, 3, 2, 1]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, ~a}
# costl:  [1, 3, 2, 1, 1]
# dict3:  {b: [True, 1], c: [False, 3], d: [False, 2], a: [True, 1], e: [True, 1]}
# costVltf:  1
# expon.pdf(costVltf) / t:  0.36787944117144233
# rand:  0.8258545131628864
# i0 :  8
# dict1:  {b: True, c: False, d: False, a: True, e: True}
# clF:  {~a | ~e, ~a}
# clT:  {~b | ~c, ~c, d | ~c, a | b}
# sT1:  {~a, ~a | ~e, a | b}
# costl:  [1]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [1, -2]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [1, -2, -2]
# sT1:  {~b | ~c, ~c, d | ~c, a | b}
# costl:  [1, -2, -2, 0]
# sT1:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# costl:  [1, -2, -2, 0, -1]
# dict3:  {b: [False, 1], c: [True, -2], d: [False, -2], a: [False, 0], e: [True, -1]}
# costVltf:  0
# expon.pdf(costVltf) / t:  1.0
# rand:  0.779593310750929
# i0 :  9
# dict1:  {b: False, c: True, d: False, a: False, e: True}
# clF:  {~c, d | ~c, a | b}
# clT:  {~b | ~c, ~a | ~e, ~a}
# dict2:  {b: False, c: True, d: False, a: False, e: True}
# vltflst:  [c, 0]
# i0 :  10
# dict1:  {b: False, c: False, d: False, a: False, e: True}
# clF:  {a | b}
# clT:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [-1]
# sT1:  {~a, ~a | ~e, d | ~c, a | b}
# costl:  [-1, 1]
# sT1:  {~a, ~a | ~e, a | b}
# costl:  [-1, 1, 2]
# sT1:  {a | b}
# costl:  [-1, 1, 2, 4]
# sT1:  {~a | ~e, a | b}
# costl:  [-1, 1, 2, 4, 3]
# dict3:  {b: [False, -1], c: [False, 1], d: [True, 2], a: [False, 4], e: [True, 3]}
# costVltf:  -1
# expon.pdf(costVltf) / t:  0.0
# rand:  0.8208533856387294
# i0 :  11
# dict1:  {b: False, c: False, d: True, a: False, e: True}
# clF:  {a | b}
# clT:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [-1]
# sT1:  {~a, ~a | ~e, d | ~c, a | b}
# costl:  [-1, 1]
# sT1:  {~a, ~a | ~e, a | b}
# costl:  [-1, 1, 2]
# sT1:  {a | b}
# costl:  [-1, 1, 2, 4]
# sT1:  {~a | ~e, a | b}
# costl:  [-1, 1, 2, 4, 3]
# dict3:  {b: [False, -1], c: [False, 1], d: [True, 2], a: [False, 4], e: [True, 3]}
# costVltf:  3
# expon.pdf(costVltf) / t:  0.049787068367863944
# rand:  0.24066551393525437
# i0 :  12
# dict1:  {b: False, c: False, d: True, a: False, e: True}
# clF:  {a | b}
# clT:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# sT1:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# costl:  [0]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b}
# costl:  [0, 1]
# sT1:  {~b | ~c, ~a | ~e, a | b}
# costl:  [0, 1, 2]
# sT1:  {~b | ~c, ~a | ~e, ~a}
# costl:  [0, 1, 2, 2]
# sT1:  {~b | ~c, ~a | ~e, ~a}
# costl:  [0, 1, 2, 2, 2]
# dict3:  {b: [True, 0], c: [False, 1], d: [True, 2], a: [True, 2], e: [False, 2]}
# costVltf:  2
# expon.pdf(costVltf) / t:  0.1353352832366127
# rand:  0.815454843352912
# i0 :  13
# dict1:  {b: True, c: False, d: True, a: True, e: False}
# clF:  {~a}
# clT:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# dict2:  {b: True, c: False, d: True, a: True, e: False}
# vltflst:  [a, 0]
# i0 :  14
# dict1:  {b: True, c: False, d: True, a: False, e: False}
# clF:  set()
# clT:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# The formula is satisfied
# anw:  {b: True, c: False, d: True, a: False, e: False}
# nsat:  [{b: True, c: False, d: True, a: False, e: True}, {b: True, c: False, d: True, a: False, e: True}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: True, a: False, e: False}]
# clauses1:  (~a, ~c, a | b, d | ~c, ~a | ~e, ~b | ~c)
# i0 :  0
# dict1:  {b: False, c: True, d: False, a: True, e: True}
# clF:  {~c, ~a | ~e, d | ~c, ~a}
# clT:  {~b | ~c, a | b}
# dict2:  {b: False, c: True, d: False, a: True, e: True}
# vltflst:  [a, 0]
# i0 :  1
# dict1:  {b: False, c: True, d: False, a: False, e: True}
# clF:  {~c, d | ~c, a | b}
# clT:  {~b | ~c, ~a | ~e, ~a}
# dict2:  {b: False, c: True, d: False, a: False, e: True}
# dict2:  {b: False, c: True, d: False, a: True, e: True}
# vltflst:  [b, 0]
# vltflst:  [b, 0, a, 0]
# i0 :  2
# dict1:  {b: True, c: True, d: False, a: True, e: True}
# clF:  {~b | ~c, ~c, ~a, ~a | ~e, d | ~c}
# clT:  {a | b}
# dict2:  {b: True, c: True, d: False, a: True, e: True}
# dict2:  {b: True, c: False, d: False, a: True, e: True}
# vltflst:  [b, 0]
# vltflst:  [b, 0, c, 0]
# i0 :  3
# dict1:  {b: False, c: False, d: False, a: True, e: True}
# clF:  {~a | ~e, ~a}
# clT:  {~b | ~c, ~c, d | ~c, a | b}
# dict2:  {b: False, c: False, d: False, a: True, e: True}
# dict2:  {b: False, c: False, d: False, a: False, e: True}
# vltflst:  [a, 0]
# vltflst:  [a, 0, e, 0]
# i0 :  4
# dict1:  {b: False, c: False, d: False, a: False, e: False}
# clF:  {a | b}
# clT:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# sT1:  {~a | ~e, a | b, d | ~c}
# costl:  [2]
# sT1:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# costl:  [2, 0]
# sT1:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# costl:  [2, 0, 0]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [2, 0, 0, -1]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [2, 0, 0, -1, -1]
# dict3:  {b: [False, 2], c: [True, 0], d: [True, 0], a: [True, -1], e: [False, -1]}
# costVltf:  2
# expon.pdf(costVltf) / t:  0.1353352832366127
# rand:  0.5383547927571546
# i0 :  5
# dict1:  {b: False, c: True, d: True, a: True, e: False}
# clF:  {~c, ~a}
# clT:  {~b | ~c, ~a | ~e, d | ~c, a | b}
# sT1:  {~b | ~c, ~a | ~e, d | ~c, ~a}
# costl:  [0]
# sT1:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# costl:  [0, -1]
# sT1:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# costl:  [0, -1, -1]
# sT1:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# costl:  [0, -1, -1, -1]
# sT1:  {~b | ~c, ~c, d | ~c, a | b}
# costl:  [0, -1, -1, -1, 0]
# dict3:  {b: [True, 0], c: [True, -1], d: [True, -1], a: [False, -1], e: [False, 0]}
# costVltf:  -1
# expon.pdf(costVltf) / t:  0.0
# rand:  0.405698970871462
# i0 :  6
# dict1:  {b: True, c: True, d: True, a: False, e: False}
# clF:  {~c, ~b | ~c}
# clT:  {~a | ~e, a | b, ~a, d | ~c}
# dict2:  {b: True, c: True, d: True, a: False, e: False}
# dict2:  {b: True, c: False, d: True, a: False, e: False}
# vltflst:  [b, 0]
# vltflst:  [b, 0, c, 0]
# i0 :  7
# dict1:  {b: False, c: False, d: True, a: False, e: False}
# clF:  {a | b}
# clT:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# dict2:  {b: False, c: False, d: True, a: False, e: False}
# dict2:  {b: False, c: False, d: True, a: True, e: False}
# vltflst:  [b, 0]
# vltflst:  [b, 0, a, 0]
# i0 :  8
# dict1:  {b: True, c: False, d: True, a: True, e: False}
# clF:  {~a}
# clT:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# sT1:  {~b | ~c, ~c, d | ~c, a | b}
# costl:  [1]
# sT1:  {a | b}
# costl:  [1, 4]
# sT1:  {d | ~c, a | b}
# costl:  [1, 4, 3]
# sT1:  {~a, ~a | ~e, d | ~c, a | b}
# costl:  [1, 4, 3, 1]
# sT1:  {~a, ~a | ~e, d | ~c, a | b}
# costl:  [1, 4, 3, 1, 1]
# dict3:  {b: [False, 1], c: [False, 4], d: [False, 3], a: [True, 1], e: [True, 1]}
# costVltf:  4
# expon.pdf(costVltf) / t:  0.01831563888873418
# rand:  0.3600387911181423
# i0 :  9
# dict1:  {b: False, c: False, d: False, a: True, e: True}
# clF:  {~a | ~e, ~a}
# clT:  {~b | ~c, ~c, d | ~c, a | b}
# dict2:  {b: False, c: False, d: False, a: True, e: True}
# vltflst:  [a, 0]
# i0 :  10
# dict1:  {b: False, c: False, d: False, a: False, e: True}
# clF:  {a | b}
# clT:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# dict2:  {b: False, c: False, d: False, a: False, e: True}
# dict2:  {b: False, c: False, d: False, a: True, e: True}
# vltflst:  [b, 0]
# vltflst:  [b, 0, a, 0]
# i0 :  11
# dict1:  {b: True, c: False, d: False, a: True, e: True}
# clF:  {~a | ~e, ~a}
# clT:  {~b | ~c, ~c, d | ~c, a | b}
# dict2:  {b: True, c: False, d: False, a: True, e: True}
# dict2:  {b: True, c: False, d: False, a: False, e: True}
# vltflst:  [a, 0]
# vltflst:  [a, 0, e, 0]
# i0 :  12
# dict1:  {b: True, c: False, d: False, a: False, e: False}
# clF:  set()
# clT:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# The formula is satisfied
# anw:  {b: True, c: False, d: False, a: False, e: False}
# nsat:  [{b: True, c: False, d: True, a: False, e: True}, {b: True, c: False, d: True, a: False, e: True}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}]
# clauses1:  (~a, ~c, a | b, d | ~c, ~a | ~e, ~b | ~c)
# i0 :  0
# dict1:  {b: True, c: False, d: False, a: False, e: False}
# clF:  set()
# clT:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# The formula is satisfied
# anw:  {b: True, c: False, d: False, a: False, e: False}
# nsat:  [{b: True, c: False, d: True, a: False, e: True}, {b: True, c: False, d: True, a: False, e: True}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}]
# clauses1:  (~a, ~c, a | b, d | ~c, ~a | ~e, ~b | ~c)
# i0 :  0
# dict1:  {b: False, c: True, d: False, a: True, e: False}
# clF:  {~c, d | ~c, ~a}
# clT:  {~b | ~c, ~a | ~e, a | b}
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [-3]
# sT1:  {~a, ~a | ~e, a | b}
# costl:  [-3, 0]
# sT1:  {~a, ~a | ~e, d | ~c, a | b}
# costl:  [-3, 0, -1]
# sT1:  {~a | ~e, a | b, d | ~c}
# costl:  [-3, 0, -1, 0]
# sT1:  {d | ~c, a | b}
# costl:  [-3, 0, -1, 0, 1]
# dict3:  {b: [False, -3], c: [False, 0], d: [False, -1], a: [False, 0], e: [False, 1]}
# costVltf:  0
# expon.pdf(costVltf) / t:  1.0
# rand:  0.991950124169868
# i0 :  1
# dict1:  {b: False, c: False, d: False, a: False, e: False}
# clF:  {a | b}
# clT:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# sT1:  {~b | ~c, ~a | ~e, d | ~c, ~a}
# costl:  [1]
# sT1:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# costl:  [1, 0]
# sT1:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# costl:  [1, 0, 0]
# sT1:  {~b | ~c, ~c, d | ~c, a | b}
# costl:  [1, 0, 0, 1]
# sT1:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# costl:  [1, 0, 0, 1, 0]
# dict3:  {b: [True, 1], c: [True, 0], d: [True, 0], a: [False, 1], e: [True, 0]}
# costVltf:  0
# expon.pdf(costVltf) / t:  1.0
# rand:  0.05895255910471742
# i0 :  2
# dict1:  {b: True, c: True, d: True, a: False, e: True}
# clF:  {~c, ~b | ~c}
# clT:  {~a | ~e, a | b, ~a, d | ~c}
# sT1:  {~b | ~c, ~c, d | ~c, a | b}
# costl:  [0]
# sT1:  {a | b}
# costl:  [0, 3]
# sT1:  {d | ~c, a | b}
# costl:  [0, 3, 2]
# sT1:  {~a, ~a | ~e, d | ~c, a | b}
# costl:  [0, 3, 2, 0]
# sT1:  {~a, ~a | ~e, d | ~c, a | b}
# costl:  [0, 3, 2, 0, 0]
# dict3:  {b: [False, 0], c: [False, 3], d: [False, 2], a: [True, 0], e: [True, 0]}
# costVltf:  0
# expon.pdf(costVltf) / t:  1.0
# rand:  0.15795400112200841
# i0 :  3
# dict1:  {b: False, c: False, d: False, a: True, e: True}
# clF:  {~a | ~e, ~a}
# clT:  {~b | ~c, ~c, d | ~c, a | b}
# dict2:  {b: False, c: False, d: False, a: True, e: True}
# vltflst:  [a, 0]
# i0 :  4
# dict1:  {b: False, c: False, d: False, a: False, e: True}
# clF:  {a | b}
# clT:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# sT1:  {~b | ~c, ~c, d | ~c, a | b}
# costl:  [1]
# sT1:  {~b | ~c, a | b, d | ~c}
# costl:  [1, 2]
# sT1:  {~b | ~c, a | b}
# costl:  [1, 2, 3]
# sT1:  {~b | ~c, ~a | ~e, ~a}
# costl:  [1, 2, 3, 2]
# sT1:  {~b | ~c, ~a | ~e, ~a}
# costl:  [1, 2, 3, 2, 2]
# dict3:  {b: [True, 1], c: [False, 2], d: [True, 3], a: [True, 2], e: [True, 2]}
# costVltf:  1
# expon.pdf(costVltf) / t:  0.36787944117144233
# rand:  0.468610635090566
# i0 :  5
# dict1:  {b: True, c: False, d: True, a: True, e: True}
# clF:  {~a | ~e, ~a}
# clT:  {~b | ~c, ~c, d | ~c, a | b}
# sT1:  {~a | ~e, a | b}
# costl:  [2]
# sT1:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# costl:  [2, -1]
# sT1:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# costl:  [2, -1, -1]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [2, -1, -1, -2]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [2, -1, -1, -2, -2]
# dict3:  {b: [False, 2], c: [True, -1], d: [False, -1], a: [True, -2], e: [False, -2]}
# costVltf:  -1
# expon.pdf(costVltf) / t:  0.0
# rand:  0.6808589275072727
# i0 :  6
# dict1:  {b: False, c: True, d: False, a: True, e: False}
# clF:  {~c, d | ~c, ~a}
# clT:  {~b | ~c, ~a | ~e, a | b}
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [-3]
# sT1:  {~a, ~a | ~e, a | b}
# costl:  [-3, 0]
# sT1:  {~a, ~a | ~e, d | ~c, a | b}
# costl:  [-3, 0, -1]
# sT1:  {d | ~c, a | b}
# costl:  [-3, 0, -1, 1]
# sT1:  {~a | ~e, a | b, d | ~c}
# costl:  [-3, 0, -1, 1, 0]
# dict3:  {b: [False, -3], c: [False, 0], d: [False, -1], a: [False, 1], e: [True, 0]}
# costVltf:  1
# expon.pdf(costVltf) / t:  0.36787944117144233
# rand:  0.13140701373807284
# i0 :  7
# dict1:  {b: False, c: False, d: False, a: False, e: True}
# clF:  {a | b}
# clT:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# sT1:  {~b | ~c, ~a | ~e, ~a}
# costl:  [2]
# sT1:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# costl:  [2, 0]
# sT1:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# costl:  [2, 0, 0]
# sT1:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# costl:  [2, 0, 0, 0]
# sT1:  {~b | ~c, ~c, d | ~c, a | b}
# costl:  [2, 0, 0, 0, 1]
# dict3:  {b: [True, 2], c: [True, 0], d: [False, 0], a: [False, 0], e: [False, 1]}
# costVltf:  0
# expon.pdf(costVltf) / t:  1.0
# rand:  0.7952637348032457
# i0 :  8
# dict1:  {b: True, c: True, d: False, a: False, e: False}
# clF:  {~c, ~b | ~c, d | ~c}
# clT:  {~a, ~a | ~e, a | b}
# dict2:  {b: True, c: True, d: False, a: False, e: False}
# dict2:  {b: True, c: False, d: False, a: False, e: False}
# vltflst:  [b, 0]
# vltflst:  [b, 0, c, 0]
# i0 :  9
# dict1:  {b: False, c: False, d: False, a: False, e: False}
# clF:  {a | b}
# clT:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# dict2:  {b: False, c: False, d: False, a: False, e: False}
# dict2:  {b: False, c: False, d: False, a: True, e: False}
# vltflst:  [b, 0]
# vltflst:  [b, 0, a, 0]
# i0 :  10
# dict1:  {b: True, c: False, d: False, a: True, e: False}
# clF:  {~a}
# clT:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# sT1:  {~b | ~c, ~c, d | ~c, a | b}
# costl:  [1]
# sT1:  {d | ~c, a | b}
# costl:  [1, 3]
# sT1:  {a | b}
# costl:  [1, 3, 4]
# sT1:  {~a, ~a | ~e, a | b}
# costl:  [1, 3, 4, 2]
# sT1:  {~a, ~a | ~e, a | b}
# costl:  [1, 3, 4, 2, 2]
# dict3:  {b: [False, 1], c: [False, 3], d: [True, 4], a: [True, 2], e: [True, 2]}
# costVltf:  1
# expon.pdf(costVltf) / t:  0.36787944117144233
# rand:  0.6719489980880917
# i0 :  11
# dict1:  {b: False, c: False, d: True, a: True, e: True}
# clF:  {~a | ~e, ~a}
# clT:  {~b | ~c, ~c, d | ~c, a | b}
# sT1:  {~b | ~c, a | b}
# costl:  [2]
# sT1:  {~b | ~c, ~c, d | ~c, a | b}
# costl:  [2, 0]
# sT1:  {~b | ~c, ~c, d | ~c, a | b}
# costl:  [2, 0, 0]
# sT1:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# costl:  [2, 0, 0, -1]
# sT1:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# costl:  [2, 0, 0, -1, -1]
# dict3:  {b: [True, 2], c: [True, 0], d: [False, 0], a: [True, -1], e: [True, -1]}
# costVltf:  0
# expon.pdf(costVltf) / t:  1.0
# rand:  0.15436656841639973
# i0 :  12
# dict1:  {b: True, c: True, d: False, a: True, e: True}
# clF:  {~b | ~c, ~c, ~a, ~a | ~e, d | ~c}
# clT:  {a | b}
# sT1:  {~b | ~c, ~a | ~e, a | b}
# costl:  [-2]
# sT1:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# costl:  [-2, -4]
# sT1:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# costl:  [-2, -4, -4]
# sT1:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# costl:  [-2, -4, -4, -4]
# sT1:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# costl:  [-2, -4, -4, -4, -4]
# dict3:  {b: [True, -2], c: [True, -4], d: [False, -4], a: [True, -4], e: [False, -4]}
# costVltf:  -4
# expon.pdf(costVltf) / t:  0.0
# rand:  0.008939878706415105
# i0 :  13
# dict1:  {b: True, c: True, d: False, a: True, e: False}
# clF:  {~c, ~b | ~c, d | ~c, ~a}
# clT:  {~a | ~e, a | b}
# dict2:  {b: True, c: True, d: False, a: True, e: False}
# vltflst:  [a, 0]
# i0 :  14
# dict1:  {b: True, c: True, d: False, a: False, e: False}
# clF:  {~c, ~b | ~c, d | ~c}
# clT:  {~a, ~a | ~e, a | b}
# sT1:  {~b | ~c, ~a | ~e, a | b}
# costl:  [0]
# sT1:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# costl:  [0, -2]
# sT1:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# costl:  [0, -2, -2]
# sT1:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# costl:  [0, -2, -2, -2]
# sT1:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# costl:  [0, -2, -2, -2, -2]
# dict3:  {b: [True, 0], c: [True, -2], d: [False, -2], a: [True, -2], e: [False, -2]}
# costVltf:  0
# expon.pdf(costVltf) / t:  1.0
# rand:  0.12941545654266495
# i0 :  15
# dict1:  {b: True, c: True, d: False, a: True, e: False}
# clF:  {~c, ~b | ~c, d | ~c, ~a}
# clT:  {~a | ~e, a | b}
# dict2:  {b: True, c: True, d: False, a: True, e: False}
# vltflst:  [c, 0]
# i0 :  16
# dict1:  {b: True, c: False, d: False, a: True, e: False}
# clF:  {~a}
# clT:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# dict2:  {b: True, c: False, d: False, a: True, e: False}
# vltflst:  [a, 0]
# i0 :  17
# dict1:  {b: True, c: False, d: False, a: False, e: False}
# clF:  set()
# clT:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# The formula is satisfied
# anw:  {b: True, c: False, d: False, a: False, e: False}
# nsat:  [{b: True, c: False, d: True, a: False, e: True}, {b: True, c: False, d: True, a: False, e: True}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}]
# clauses1:  (~a, ~c, a | b, d | ~c, ~a | ~e, ~b | ~c)
# i0 :  0
# dict1:  {b: False, c: False, d: True, a: False, e: False}
# clF:  {a | b}
# clT:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# dict2:  {b: False, c: False, d: True, a: False, e: False}
# dict2:  {b: False, c: False, d: True, a: True, e: False}
# vltflst:  [b, 0]
# vltflst:  [b, 0, a, 0]
# i0 :  1
# dict1:  {b: True, c: False, d: True, a: True, e: False}
# clF:  {~a}
# clT:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# sT1:  {~a | ~e, a | b, d | ~c}
# costl:  [2]
# sT1:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# costl:  [2, 0]
# sT1:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# costl:  [2, 0, 0]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [2, 0, 0, -1]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [2, 0, 0, -1, -1]
# dict3:  {b: [False, 2], c: [True, 0], d: [True, 0], a: [True, -1], e: [False, -1]}
# costVltf:  -1
# expon.pdf(costVltf) / t:  0.0
# rand:  0.6032049461761373
# i0 :  2
# dict1:  {b: False, c: True, d: True, a: True, e: False}
# clF:  {~c, ~a}
# clT:  {~b | ~c, ~a | ~e, d | ~c, a | b}
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [-2]
# sT1:  {~a, ~a | ~e, a | b}
# costl:  [-2, 1]
# sT1:  {~a, ~a | ~e, d | ~c, a | b}
# costl:  [-2, 1, 0]
# sT1:  {d | ~c, a | b}
# costl:  [-2, 1, 0, 2]
# sT1:  {~a | ~e, a | b, d | ~c}
# costl:  [-2, 1, 0, 2, 1]
# dict3:  {b: [False, -2], c: [False, 1], d: [False, 0], a: [False, 2], e: [True, 1]}
# costVltf:  -2
# expon.pdf(costVltf) / t:  0.0
# rand:  0.4569460052697015
# i0 :  3
# dict1:  {b: False, c: False, d: False, a: False, e: True}
# clF:  {a | b}
# clT:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# dict2:  {b: False, c: False, d: False, a: False, e: True}
# dict2:  {b: False, c: False, d: False, a: True, e: True}
# vltflst:  [b, 0]
# vltflst:  [b, 0, a, 0]
# i0 :  4
# dict1:  {b: True, c: False, d: False, a: True, e: True}
# clF:  {~a | ~e, ~a}
# clT:  {~b | ~c, ~c, d | ~c, a | b}
# dict2:  {b: True, c: False, d: False, a: True, e: True}
# dict2:  {b: True, c: False, d: False, a: False, e: True}
# vltflst:  [a, 0]
# vltflst:  [a, 0, e, 0]
# i0 :  5
# dict1:  {b: True, c: False, d: False, a: False, e: False}
# clF:  set()
# clT:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# The formula is satisfied
# anw:  {b: True, c: False, d: False, a: False, e: False}
# nsat:  [{b: True, c: False, d: True, a: False, e: True}, {b: True, c: False, d: True, a: False, e: True}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}]
# clauses1:  (~a, ~c, a | b, d | ~c, ~a | ~e, ~b | ~c)
# i0 :  0
# dict1:  {b: False, c: True, d: False, a: True, e: True}
# clF:  {~c, ~a | ~e, d | ~c, ~a}
# clT:  {~b | ~c, a | b}
# dict2:  {b: False, c: True, d: False, a: True, e: True}
# vltflst:  [c, 0]
# i0 :  1
# dict1:  {b: False, c: False, d: False, a: True, e: True}
# clF:  {~a | ~e, ~a}
# clT:  {~b | ~c, ~c, d | ~c, a | b}
# dict2:  {b: False, c: False, d: False, a: True, e: True}
# dict2:  {b: False, c: False, d: False, a: False, e: True}
# vltflst:  [a, 0]
# vltflst:  [a, 0, e, 0]
# i0 :  2
# dict1:  {b: False, c: False, d: False, a: False, e: False}
# clF:  {a | b}
# clT:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# dict2:  {b: False, c: False, d: False, a: False, e: False}
# dict2:  {b: False, c: False, d: False, a: True, e: False}
# vltflst:  [b, 0]
# vltflst:  [b, 0, a, 0]
# i0 :  3
# dict1:  {b: True, c: False, d: False, a: True, e: False}
# clF:  {~a}
# clT:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [-1]
# sT1:  {~a, ~a | ~e, a | b}
# costl:  [-1, 2]
# sT1:  {~a, ~a | ~e, d | ~c, a | b}
# costl:  [-1, 2, 1]
# sT1:  {d | ~c, a | b}
# costl:  [-1, 2, 1, 3]
# sT1:  {~a | ~e, a | b, d | ~c}
# costl:  [-1, 2, 1, 3, 2]
# dict3:  {b: [False, -1], c: [False, 2], d: [False, 1], a: [False, 3], e: [True, 2]}
# costVltf:  -1
# expon.pdf(costVltf) / t:  0.0
# rand:  0.110430384837506
# i0 :  4
# dict1:  {b: False, c: False, d: False, a: False, e: True}
# clF:  {a | b}
# clT:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# sT1:  {~a | ~e, a | b}
# costl:  [3]
# sT1:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# costl:  [3, 0]
# sT1:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# costl:  [3, 0, 0]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [3, 0, 0, -1]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [3, 0, 0, -1, -1]
# dict3:  {b: [False, 3], c: [True, 0], d: [False, 0], a: [True, -1], e: [False, -1]}
# costVltf:  0
# expon.pdf(costVltf) / t:  1.0
# rand:  0.04792496068435448
# i0 :  5
# dict1:  {b: False, c: True, d: False, a: True, e: False}
# clF:  {~c, d | ~c, ~a}
# clT:  {~b | ~c, ~a | ~e, a | b}
# dict2:  {b: False, c: True, d: False, a: True, e: False}
# vltflst:  [c, 0]
# i0 :  6
# dict1:  {b: False, c: False, d: False, a: True, e: False}
# clF:  {~a}
# clT:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# sT1:  {d | ~c, a | b}
# costl:  [3]
# sT1:  {~b | ~c, ~c, d | ~c, a | b}
# costl:  [3, 1]
# sT1:  {~b | ~c, ~c, d | ~c, a | b}
# costl:  [3, 1, 1]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [3, 1, 1, -1]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [3, 1, 1, -1, -1]
# dict3:  {b: [False, 3], c: [True, 1], d: [True, 1], a: [True, -1], e: [True, -1]}
# costVltf:  1
# expon.pdf(costVltf) / t:  0.36787944117144233
# rand:  0.4375285553912026
# i0 :  7
# dict1:  {b: False, c: True, d: True, a: True, e: True}
# clF:  {~c, ~a | ~e, ~a}
# clT:  {~b | ~c, a | b, d | ~c}
# sT1:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# costl:  [-2]
# sT1:  {~b | ~c, ~a | ~e, ~a}
# costl:  [-2, 0]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, ~a}
# costl:  [-2, 0, -1]
# sT1:  {~b | ~c, a | b, d | ~c}
# costl:  [-2, 0, -1, 0]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b}
# costl:  [-2, 0, -1, 0, -1]
# dict3:  {b: [True, -2], c: [False, 0], d: [False, -1], a: [False, 0], e: [True, -1]}
# costVltf:  -1
# expon.pdf(costVltf) / t:  0.0
# rand:  0.5580209867839887
# i0 :  8
# dict1:  {b: True, c: False, d: False, a: False, e: True}
# clF:  set()
# clT:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# The formula is satisfied
# anw:  {b: True, c: False, d: False, a: False, e: True}
# nsat:  [{b: True, c: False, d: True, a: False, e: True}, {b: True, c: False, d: True, a: False, e: True}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: False, a: False, e: True}]
# clauses1:  (~a, ~c, a | b, d | ~c, ~a | ~e, ~b | ~c)
# i0 :  0
# dict1:  {b: False, c: True, d: True, a: False, e: False}
# clF:  {~c, a | b}
# clT:  {~b | ~c, ~a | ~e, d | ~c, ~a}
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [-2]
# sT1:  {~a, ~a | ~e, d | ~c, a | b}
# costl:  [-2, 0]
# sT1:  {~a, ~a | ~e, a | b}
# costl:  [-2, 0, 1]
# sT1:  {a | b}
# costl:  [-2, 0, 1, 3]
# sT1:  {~a | ~e, a | b}
# costl:  [-2, 0, 1, 3, 2]
# dict3:  {b: [False, -2], c: [False, 0], d: [True, 1], a: [False, 3], e: [True, 2]}
# costVltf:  3
# expon.pdf(costVltf) / t:  0.049787068367863944
# rand:  0.13966342937849452
# i0 :  1
# dict1:  {b: False, c: False, d: True, a: False, e: True}
# clF:  {a | b}
# clT:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# sT1:  {~a, ~a | ~e, a | b}
# costl:  [2]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [2, -1]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [2, -1, -1]
# sT1:  {~b | ~c, ~c, d | ~c, a | b}
# costl:  [2, -1, -1, 1]
# sT1:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# costl:  [2, -1, -1, 1, 0]
# dict3:  {b: [False, 2], c: [True, -1], d: [False, -1], a: [False, 1], e: [True, 0]}
# costVltf:  1
# expon.pdf(costVltf) / t:  0.36787944117144233
# rand:  0.40840339484863264
# i0 :  2
# dict1:  {b: False, c: True, d: False, a: False, e: True}
# clF:  {~c, d | ~c, a | b}
# clT:  {~b | ~c, ~a | ~e, ~a}
# dict2:  {b: False, c: True, d: False, a: False, e: True}
# dict2:  {b: False, c: True, d: False, a: True, e: True}
# vltflst:  [b, 0]
# vltflst:  [b, 0, a, 0]
# i0 :  3
# dict1:  {b: True, c: True, d: False, a: True, e: True}
# clF:  {~b | ~c, ~c, ~a, ~a | ~e, d | ~c}
# clT:  {a | b}
# sT1:  {~b | ~c, a | b}
# costl:  [-1]
# sT1:  {~b | ~c, ~c, d | ~c, a | b}
# costl:  [-1, -3]
# sT1:  {~b | ~c, ~c, d | ~c, a | b}
# costl:  [-1, -3, -3]
# sT1:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# costl:  [-1, -3, -3, -4]
# sT1:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# costl:  [-1, -3, -3, -4, -4]
# dict3:  {b: [True, -1], c: [True, -3], d: [False, -3], a: [True, -4], e: [True, -4]}
# costVltf:  -4
# expon.pdf(costVltf) / t:  0.0
# rand:  0.02358370580232194
# i0 :  4
# dict1:  {b: True, c: True, d: False, a: True, e: True}
# clF:  {~b | ~c, ~c, ~a, ~a | ~e, d | ~c}
# clT:  {a | b}
# dict2:  {b: True, c: True, d: False, a: True, e: True}
# dict2:  {b: True, c: False, d: False, a: True, e: True}
# vltflst:  [b, 0]
# vltflst:  [b, 0, c, 0]
# i0 :  5
# dict1:  {b: False, c: False, d: False, a: True, e: True}
# clF:  {~a | ~e, ~a}
# clT:  {~b | ~c, ~c, d | ~c, a | b}
# sT1:  {~a | ~e, a | b}
# costl:  [2]
# sT1:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# costl:  [2, -1]
# sT1:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# costl:  [2, -1, -1]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [2, -1, -1, -2]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [2, -1, -1, -2, -2]
# dict3:  {b: [False, 2], c: [True, -1], d: [False, -1], a: [True, -2], e: [False, -2]}
# costVltf:  -1
# expon.pdf(costVltf) / t:  0.0
# rand:  0.922771184803131
# i0 :  6
# dict1:  {b: False, c: True, d: False, a: True, e: False}
# clF:  {~c, d | ~c, ~a}
# clT:  {~b | ~c, ~a | ~e, a | b}
# dict2:  {b: False, c: True, d: False, a: True, e: False}
# vltflst:  [c, 0]
# i0 :  7
# dict1:  {b: False, c: False, d: False, a: True, e: False}
# clF:  {~a}
# clT:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# sT1:  {~a | ~e, a | b, d | ~c}
# costl:  [2]
# sT1:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# costl:  [2, 0]
# sT1:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# costl:  [2, 0, 0]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [2, 0, 0, -1]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [2, 0, 0, -1, -1]
# dict3:  {b: [False, 2], c: [True, 0], d: [True, 0], a: [True, -1], e: [False, -1]}
# costVltf:  0
# expon.pdf(costVltf) / t:  1.0
# rand:  0.3007338535861527
# i0 :  8
# dict1:  {b: False, c: True, d: True, a: True, e: False}
# clF:  {~c, ~a}
# clT:  {~b | ~c, ~a | ~e, d | ~c, a | b}
# dict2:  {b: False, c: True, d: True, a: True, e: False}
# vltflst:  [a, 0]
# i0 :  9
# dict1:  {b: False, c: True, d: True, a: False, e: False}
# clF:  {~c, a | b}
# clT:  {~b | ~c, ~a | ~e, d | ~c, ~a}
# dict2:  {b: False, c: True, d: True, a: False, e: False}
# vltflst:  [c, 0]
# i0 :  10
# dict1:  {b: False, c: False, d: True, a: False, e: False}
# clF:  {a | b}
# clT:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [-1]
# sT1:  {~a, ~a | ~e, d | ~c, a | b}
# costl:  [-1, 1]
# sT1:  {~a, ~a | ~e, a | b}
# costl:  [-1, 1, 2]
# sT1:  {a | b}
# costl:  [-1, 1, 2, 4]
# sT1:  {~a | ~e, a | b}
# costl:  [-1, 1, 2, 4, 3]
# dict3:  {b: [False, -1], c: [False, 1], d: [True, 2], a: [False, 4], e: [True, 3]}
# costVltf:  1
# expon.pdf(costVltf) / t:  0.36787944117144233
# rand:  0.4685490096134679
# i0 :  11
# dict1:  {b: False, c: False, d: True, a: False, e: True}
# clF:  {a | b}
# clT:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# sT1:  {a | b}
# costl:  [4]
# sT1:  {~b | ~c, ~c, d | ~c, a | b}
# costl:  [4, 1]
# sT1:  {~b | ~c, ~c, d | ~c, a | b}
# costl:  [4, 1, 1]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [4, 1, 1, -1]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [4, 1, 1, -1, -1]
# dict3:  {b: [False, 4], c: [True, 1], d: [False, 1], a: [True, -1], e: [True, -1]}
# costVltf:  -1
# expon.pdf(costVltf) / t:  0.0
# rand:  0.391657335034151
# i0 :  12
# dict1:  {b: False, c: True, d: False, a: True, e: True}
# clF:  {~c, ~a | ~e, d | ~c, ~a}
# clT:  {~b | ~c, a | b}
# sT1:  {d | ~c, a | b}
# costl:  [0]
# sT1:  {~b | ~c, ~c, d | ~c, a | b}
# costl:  [0, -2]
# sT1:  {~b | ~c, ~c, d | ~c, a | b}
# costl:  [0, -2, -2]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [0, -2, -2, -4]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [0, -2, -2, -4, -4]
# dict3:  {b: [False, 0], c: [True, -2], d: [True, -2], a: [True, -4], e: [True, -4]}
# costVltf:  -4
# expon.pdf(costVltf) / t:  0.0
# rand:  0.8612825220487899
# i0 :  13
# dict1:  {b: False, c: True, d: True, a: True, e: True}
# clF:  {~c, ~a | ~e, ~a}
# clT:  {~b | ~c, a | b, d | ~c}
# sT1:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# costl:  [-2]
# sT1:  {~b | ~c, ~a | ~e, ~a}
# costl:  [-2, 0]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, ~a}
# costl:  [-2, 0, -1]
# sT1:  {~b | ~c, a | b, d | ~c}
# costl:  [-2, 0, -1, 0]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b}
# costl:  [-2, 0, -1, 0, -1]
# dict3:  {b: [True, -2], c: [False, 0], d: [False, -1], a: [False, 0], e: [True, -1]}
# costVltf:  0
# expon.pdf(costVltf) / t:  1.0
# rand:  0.7789165097774085
# i0 :  14
# dict1:  {b: True, c: False, d: False, a: False, e: True}
# clF:  set()
# clT:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# The formula is satisfied
# anw:  {b: True, c: False, d: False, a: False, e: True}
# nsat:  [{b: True, c: False, d: True, a: False, e: True}, {b: True, c: False, d: True, a: False, e: True}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: False, a: False, e: True}, {b: True, c: False, d: False, a: False, e: True}]
# clauses1:  (~a, ~c, a | b, d | ~c, ~a | ~e, ~b | ~c)
# i0 :  0
# dict1:  {b: False, c: False, d: True, a: False, e: False}
# clF:  {a | b}
# clT:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# sT1:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# costl:  [0]
# sT1:  {~b | ~c, ~a | ~e, ~a}
# costl:  [0, 2]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, ~a}
# costl:  [0, 2, 1]
# sT1:  {~b | ~c, a | b, d | ~c}
# costl:  [0, 2, 1, 2]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b}
# costl:  [0, 2, 1, 2, 1]
# dict3:  {b: [True, 0], c: [False, 2], d: [False, 1], a: [False, 2], e: [True, 1]}
# costVltf:  0
# expon.pdf(costVltf) / t:  1.0
# rand:  0.2665580334423757
# i0 :  1
# dict1:  {b: True, c: False, d: False, a: False, e: True}
# clF:  set()
# clT:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# The formula is satisfied
# anw:  {b: True, c: False, d: False, a: False, e: True}
# nsat:  [{b: True, c: False, d: True, a: False, e: True}, {b: True, c: False, d: True, a: False, e: True}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: False, a: False, e: True}, {b: True, c: False, d: False, a: False, e: True}, {b: True, c: False, d: False, a: False, e: True}]
# clauses1:  (~a, ~c, a | b, d | ~c, ~a | ~e, ~b | ~c)
# i0 :  0
# dict1:  {b: True, c: True, d: True, a: True, e: True}
# clF:  {~b | ~c, ~c, ~a | ~e, ~a}
# clT:  {a | b, d | ~c}
# sT1:  {~b | ~c, a | b, d | ~c}
# costl:  [-1]
# sT1:  {~b | ~c, ~c, d | ~c, a | b}
# costl:  [-1, -2]
# sT1:  {~b | ~c, ~c, d | ~c, a | b}
# costl:  [-1, -2, -2]
# sT1:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# costl:  [-1, -2, -2, -3]
# sT1:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# costl:  [-1, -2, -2, -3, -3]
# dict3:  {b: [True, -1], c: [True, -2], d: [True, -2], a: [True, -3], e: [True, -3]}
# costVltf:  -3
# expon.pdf(costVltf) / t:  0.0
# rand:  0.1585603709738519
# i0 :  1
# dict1:  {b: True, c: True, d: True, a: True, e: True}
# clF:  {~b | ~c, ~c, ~a | ~e, ~a}
# clT:  {a | b, d | ~c}
# sT1:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# costl:  [-3]
# sT1:  {~b | ~c, ~a | ~e, ~a}
# costl:  [-3, -1]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, ~a}
# costl:  [-3, -1, -2]
# sT1:  {~b | ~c, a | b, d | ~c}
# costl:  [-3, -1, -2, -1]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b}
# costl:  [-3, -1, -2, -1, -2]
# dict3:  {b: [True, -3], c: [False, -1], d: [False, -2], a: [False, -1], e: [True, -2]}
# costVltf:  -1
# expon.pdf(costVltf) / t:  0.0
# rand:  0.7536618324437939
# i0 :  2
# dict1:  {b: True, c: False, d: False, a: False, e: True}
# clF:  set()
# clT:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# The formula is satisfied
# anw:  {b: True, c: False, d: False, a: False, e: True}
# nsat:  [{b: True, c: False, d: True, a: False, e: True}, {b: True, c: False, d: True, a: False, e: True}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: False, a: False, e: True}, {b: True, c: False, d: False, a: False, e: True}, {b: True, c: False, d: False, a: False, e: True}, {b: True, c: False, d: False, a: False, e: True}]
# clauses1:  (~a, ~c, a | b, d | ~c, ~a | ~e, ~b | ~c)
# i0 :  0
# dict1:  {b: False, c: True, d: True, a: True, e: False}
# clF:  {~c, ~a}
# clT:  {~b | ~c, ~a | ~e, d | ~c, a | b}
# sT1:  {~a, ~a | ~e, d | ~c, a | b}
# costl:  [0]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [0, -2]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [0, -2, -2]
# sT1:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# costl:  [0, -2, -2, -1]
# sT1:  {~b | ~c, ~c, d | ~c, a | b}
# costl:  [0, -2, -2, -1, 0]
# dict3:  {b: [False, 0], c: [True, -2], d: [True, -2], a: [False, -1], e: [False, 0]}
# costVltf:  -2
# expon.pdf(costVltf) / t:  0.0
# rand:  0.07310283763716652
# i0 :  1
# dict1:  {b: False, c: True, d: True, a: False, e: False}
# clF:  {~c, a | b}
# clT:  {~b | ~c, ~a | ~e, d | ~c, ~a}
# sT1:  {~a | ~e, a | b, d | ~c}
# costl:  [1]
# sT1:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# costl:  [1, -1]
# sT1:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# costl:  [1, -1, -1]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [1, -1, -1, -2]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [1, -1, -1, -2, -2]
# dict3:  {b: [False, 1], c: [True, -1], d: [True, -1], a: [True, -2], e: [False, -2]}
# costVltf:  -1
# expon.pdf(costVltf) / t:  0.0
# rand:  0.5298412184969478
# i0 :  2
# dict1:  {b: False, c: True, d: True, a: True, e: False}
# clF:  {~c, ~a}
# clT:  {~b | ~c, ~a | ~e, d | ~c, a | b}
# dict2:  {b: False, c: True, d: True, a: True, e: False}
# vltflst:  [c, 0]
# i0 :  3
# dict1:  {b: False, c: False, d: True, a: True, e: False}
# clF:  {~a}
# clT:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# sT1:  {~a, ~a | ~e, a | b}
# costl:  [2]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [2, -1]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [2, -1, -1]
# sT1:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# costl:  [2, -1, -1, 0]
# sT1:  {~b | ~c, ~c, d | ~c, a | b}
# costl:  [2, -1, -1, 0, 1]
# dict3:  {b: [False, 2], c: [True, -1], d: [False, -1], a: [False, 0], e: [False, 1]}
# costVltf:  1
# expon.pdf(costVltf) / t:  0.36787944117144233
# rand:  0.001027297535221794
# i0 :  4
# dict1:  {b: False, c: True, d: False, a: False, e: False}
# clF:  {~c, d | ~c, a | b}
# clT:  {~b | ~c, ~a | ~e, ~a}
# sT1:  {d | ~c, a | b}
# costl:  [1]
# sT1:  {~b | ~c, ~c, d | ~c, a | b}
# costl:  [1, -1]
# sT1:  {~b | ~c, ~c, d | ~c, a | b}
# costl:  [1, -1, -1]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [1, -1, -1, -3]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [1, -1, -1, -3, -3]
# dict3:  {b: [False, 1], c: [True, -1], d: [True, -1], a: [True, -3], e: [True, -3]}
# costVltf:  -1
# expon.pdf(costVltf) / t:  0.0
# rand:  0.5463643185519269
# i0 :  5
# dict1:  {b: False, c: True, d: True, a: True, e: True}
# clF:  {~c, ~a | ~e, ~a}
# clT:  {~b | ~c, a | b, d | ~c}
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [-3]
# sT1:  {~a, ~a | ~e, d | ~c, a | b}
# costl:  [-3, -1]
# sT1:  {~a, ~a | ~e, a | b}
# costl:  [-3, -1, 0]
# sT1:  {a | b}
# costl:  [-3, -1, 0, 2]
# sT1:  {~a | ~e, a | b}
# costl:  [-3, -1, 0, 2, 1]
# dict3:  {b: [False, -3], c: [False, -1], d: [True, 0], a: [False, 2], e: [True, 1]}
# costVltf:  1
# expon.pdf(costVltf) / t:  0.36787944117144233
# rand:  0.7387123498714427
# i0 :  6
# dict1:  {b: False, c: False, d: True, a: False, e: True}
# clF:  {a | b}
# clT:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# sT1:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# costl:  [0]
# sT1:  {~b | ~c, ~a | ~e, ~a}
# costl:  [0, 2]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, ~a}
# costl:  [0, 2, 1]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b}
# costl:  [0, 2, 1, 1]
# sT1:  {~b | ~c, a | b, d | ~c}
# costl:  [0, 2, 1, 1, 2]
# dict3:  {b: [True, 0], c: [False, 2], d: [False, 1], a: [False, 1], e: [False, 2]}
# costVltf:  0
# expon.pdf(costVltf) / t:  1.0
# rand:  0.485347743216198
# i0 :  7
# dict1:  {b: True, c: False, d: False, a: False, e: False}
# clF:  set()
# clT:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# The formula is satisfied
# anw:  {b: True, c: False, d: False, a: False, e: False}
# nsat:  [{b: True, c: False, d: True, a: False, e: True}, {b: True, c: False, d: True, a: False, e: True}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: False, a: False, e: True}, {b: True, c: False, d: False, a: False, e: True}, {b: True, c: False, d: False, a: False, e: True}, {b: True, c: False, d: False, a: False, e: True}, {b: True, c: False, d: False, a: False, e: False}]
# clauses1:  (~a, ~c, a | b, d | ~c, ~a | ~e, ~b | ~c)
# i0 :  0
# dict1:  {b: False, c: True, d: True, a: False, e: True}
# clF:  {~c, a | b}
# clT:  {~b | ~c, ~a | ~e, d | ~c, ~a}
# sT1:  {~b | ~c, ~c, d | ~c, a | b}
# costl:  [0]
# sT1:  {~b | ~c, a | b, d | ~c}
# costl:  [0, 1]
# sT1:  {~b | ~c, a | b}
# costl:  [0, 1, 2]
# sT1:  {~b | ~c, ~a | ~e, ~a}
# costl:  [0, 1, 2, 1]
# sT1:  {~b | ~c, ~a | ~e, ~a}
# costl:  [0, 1, 2, 1, 1]
# dict3:  {b: [True, 0], c: [False, 1], d: [True, 2], a: [True, 1], e: [True, 1]}
# costVltf:  2
# expon.pdf(costVltf) / t:  0.1353352832366127
# rand:  0.15577412196247353
# i0 :  1
# dict1:  {b: True, c: False, d: True, a: True, e: True}
# clF:  {~a | ~e, ~a}
# clT:  {~b | ~c, ~c, d | ~c, a | b}
# dict2:  {b: True, c: False, d: True, a: True, e: True}
# dict2:  {b: True, c: False, d: True, a: False, e: True}
# vltflst:  [a, 0]
# vltflst:  [a, 0, e, 0]
# i0 :  2
# dict1:  {b: True, c: False, d: True, a: False, e: False}
# clF:  set()
# clT:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# The formula is satisfied
# anw:  {b: True, c: False, d: True, a: False, e: False}
# ...
# i0 :  0
# dict1:  {b: True, c: False, d: False, a: True, e: True}
# clF:  {~a | ~e, ~a}
# clT:  {~b | ~c, ~c, d | ~c, a | b}
# sT1:  {~b | ~c, ~a | ~e, a | b}
# costl:  [1]
# sT1:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# costl:  [1, -1]
# sT1:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# costl:  [1, -1, -1]
# sT1:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# costl:  [1, -1, -1, -1]
# sT1:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# costl:  [1, -1, -1, -1, -1]
# dict3:  {b: [True, 1], c: [True, -1], d: [False, -1], a: [True, -1], e: [False, -1]}
# costVltf:  -1
# expon.pdf(costVltf) / t:  0.0
# rand:  0.1352743817969777
# i0 :  1
# dict1:  {b: True, c: True, d: False, a: True, e: False}
# clF:  {~c, ~b | ~c, d | ~c, ~a}
# clT:  {~a | ~e, a | b}
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [-4]
# sT1:  {~a, ~a | ~e, d | ~c, a | b}
# costl:  [-4, -2]
# sT1:  {~a, ~a | ~e, a | b}
# costl:  [-4, -2, -1]
# sT1:  {a | b}
# costl:  [-4, -2, -1, 1]
# sT1:  {~a | ~e, a | b}
# costl:  [-4, -2, -1, 1, 0]
# dict3:  {b: [False, -4], c: [False, -2], d: [True, -1], a: [False, 1], e: [True, 0]}
# costVltf:  -4
# expon.pdf(costVltf) / t:  0.0
# rand:  0.9125283638614333
# i0 :  2
# dict1:  {b: False, c: False, d: True, a: False, e: True}
# clF:  {a | b}
# clT:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# sT1:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# costl:  [0]
# sT1:  {~a | ~e, a | b, d | ~c}
# costl:  [0, 2]
# sT1:  {~a | ~e, a | b}
# costl:  [0, 2, 3]
# sT1:  {~a, ~a | ~e, a | b}
# costl:  [0, 2, 3, 2]
# sT1:  {~a, ~a | ~e, a | b}
# costl:  [0, 2, 3, 2, 2]
# dict3:  {b: [False, 0], c: [False, 2], d: [True, 3], a: [True, 2], e: [False, 2]}
# costVltf:  3
# expon.pdf(costVltf) / t:  0.049787068367863944
# rand:  0.586838283160876
# i0 :  3
# dict1:  {b: False, c: False, d: True, a: True, e: False}
# clF:  {~a}
# clT:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# sT1:  {d | ~c, a | b}
# costl:  [3]
# sT1:  {~b | ~c, ~c, d | ~c, a | b}
# costl:  [3, 1]
# sT1:  {~b | ~c, ~c, d | ~c, a | b}
# costl:  [3, 1, 1]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [3, 1, 1, -1]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [3, 1, 1, -1, -1]
# dict3:  {b: [False, 3], c: [True, 1], d: [True, 1], a: [True, -1], e: [True, -1]}
# costVltf:  3
# expon.pdf(costVltf) / t:  0.049787068367863944
# rand:  0.6237849280633969
# i0 :  4
# dict1:  {b: False, c: True, d: True, a: True, e: True}
# clF:  {~c, ~a | ~e, ~a}
# clT:  {~b | ~c, a | b, d | ~c}
# sT1:  {~a, ~a | ~e, d | ~c, a | b}
# costl:  [-1]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [-1, -3]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [-1, -3, -3]
# sT1:  {~b | ~c, ~c, d | ~c, a | b}
# costl:  [-1, -3, -3, -1]
# sT1:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# costl:  [-1, -3, -3, -1, -2]
# dict3:  {b: [False, -1], c: [True, -3], d: [True, -3], a: [False, -1], e: [True, -2]}
# costVltf:  -3
# expon.pdf(costVltf) / t:  0.0
# rand:  0.8475197505205069
# i0 :  5
# dict1:  {b: False, c: True, d: True, a: False, e: True}
# clF:  {~c, a | b}
# clT:  {~b | ~c, ~a | ~e, d | ~c, ~a}
# sT1:  {~b | ~c, ~a | ~e, ~a}
# costl:  [1]
# sT1:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# costl:  [1, -1]
# sT1:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# costl:  [1, -1, -1]
# sT1:  {~b | ~c, ~c, d | ~c, a | b}
# costl:  [1, -1, -1, 0]
# sT1:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# costl:  [1, -1, -1, 0, -1]
# dict3:  {b: [True, 1], c: [True, -1], d: [False, -1], a: [False, 0], e: [True, -1]}
# costVltf:  -1
# expon.pdf(costVltf) / t:  0.0
# rand:  0.6522205829402971
# i0 :  6
# dict1:  {b: True, c: True, d: False, a: False, e: True}
# clF:  {~c, ~b | ~c, d | ~c}
# clT:  {~a, ~a | ~e, a | b}
# sT1:  {~b | ~c, ~a | ~e, ~a}
# costl:  [0]
# sT1:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# costl:  [0, -2]
# sT1:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# costl:  [0, -2, -2]
# sT1:  {~b | ~c, ~c, d | ~c, a | b}
# costl:  [0, -2, -2, -1]
# sT1:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# costl:  [0, -2, -2, -1, -2]
# dict3:  {b: [True, 0], c: [True, -2], d: [False, -2], a: [False, -1], e: [True, -2]}
# costVltf:  -2
# expon.pdf(costVltf) / t:  0.0
# rand:  0.9937701940453081
# i0 :  7
# dict1:  {b: True, c: True, d: False, a: False, e: True}
# clF:  {~c, ~b | ~c, d | ~c}
# clT:  {~a, ~a | ~e, a | b}
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b}
# costl:  [-1]
# sT1:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# costl:  [-1, -2]
# sT1:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# costl:  [-1, -2, -2]
# sT1:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# costl:  [-1, -2, -2, -2]
# sT1:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# costl:  [-1, -2, -2, -2, -2]
# dict3:  {b: [True, -1], c: [True, -2], d: [True, -2], a: [True, -2], e: [False, -2]}
# costVltf:  -2
# expon.pdf(costVltf) / t:  0.0
# rand:  0.5013830658822379
# i0 :  8
# dict1:  {b: True, c: True, d: True, a: True, e: False}
# clF:  {~c, ~b | ~c, ~a}
# clT:  {~a | ~e, d | ~c, a | b}
# dict2:  {b: True, c: True, d: True, a: True, e: False}
# vltflst:  [a, 0]
# i0 :  9
# dict1:  {b: True, c: True, d: True, a: False, e: False}
# clF:  {~c, ~b | ~c}
# clT:  {~a | ~e, a | b, ~a, d | ~c}
# sT1:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# costl:  [-1]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b}
# costl:  [-1, 0]
# sT1:  {~b | ~c, ~a | ~e, a | b}
# costl:  [-1, 0, 1]
# sT1:  {~b | ~c, ~a | ~e, ~a}
# costl:  [-1, 0, 1, 1]
# sT1:  {~b | ~c, ~a | ~e, ~a}
# costl:  [-1, 0, 1, 1, 1]
# dict3:  {b: [True, -1], c: [False, 0], d: [True, 1], a: [True, 1], e: [False, 1]}
# costVltf:  1
# expon.pdf(costVltf) / t:  0.36787944117144233
# rand:  0.011249200643578261
# i0 :  10
# dict1:  {b: True, c: False, d: True, a: True, e: False}
# clF:  {~a}
# clT:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# dict2:  {b: True, c: False, d: True, a: True, e: False}
# vltflst:  [a, 0]
# i0 :  11
# dict1:  {b: True, c: False, d: True, a: False, e: False}
# clF:  set()
# clT:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# The formula is satisfied
# anw:  {b: True, c: False, d: True, a: False, e: False}
# nsat:  [{b: True, c: False, d: True, a: False, e: True}, {b: True, c: False, d: True, a: False, e: True}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: False, a: False, e: True}, {b: True, c: False, d: False, a: False, e: True}, {b: True, c: False, d: False, a: False, e: True}, {b: True, c: False, d: False, a: False, e: True}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: True, a: False, e: False}]
# clauses1:  (~a, ~c, a | b, d | ~c, ~a | ~e, ~b | ~c)
# i0 :  0
# dict1:  {b: True, c: True, d: True, a: False, e: False}
# clF:  {~c, ~b | ~c}
# clT:  {~a | ~e, a | b, ~a, d | ~c}
# dict2:  {b: True, c: True, d: True, a: False, e: False}
# dict2:  {b: True, c: False, d: True, a: False, e: False}
# vltflst:  [b, 0]
# vltflst:  [b, 0, c, 0]
# i0 :  1
# dict1:  {b: False, c: False, d: True, a: False, e: False}
# clF:  {a | b}
# clT:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# dict2:  {b: False, c: False, d: True, a: False, e: False}
# dict2:  {b: False, c: False, d: True, a: True, e: False}
# vltflst:  [b, 0]
# vltflst:  [b, 0, a, 0]
# i0 :  2
# dict1:  {b: True, c: False, d: True, a: True, e: False}
# clF:  {~a}
# clT:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# sT1:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# costl:  [0]
# sT1:  {~b | ~c, ~a | ~e, ~a}
# costl:  [0, 2]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, ~a}
# costl:  [0, 2, 1]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b}
# costl:  [0, 2, 1, 1]
# sT1:  {~b | ~c, a | b, d | ~c}
# costl:  [0, 2, 1, 1, 2]
# dict3:  {b: [True, 0], c: [False, 2], d: [False, 1], a: [False, 1], e: [False, 2]}
# costVltf:  1
# expon.pdf(costVltf) / t:  0.36787944117144233
# rand:  0.027762267761482495
# i0 :  3
# dict1:  {b: True, c: False, d: False, a: False, e: False}
# clF:  set()
# clT:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# The formula is satisfied
# anw:  {b: True, c: False, d: False, a: False, e: False}
# nsat:  [{b: True, c: False, d: True, a: False, e: True}, {b: True, c: False, d: True, a: False, e: True}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: False, a: False, e: True}, {b: True, c: False, d: False, a: False, e: True}, {b: True, c: False, d: False, a: False, e: True}, {b: True, c: False, d: False, a: False, e: True}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}]
# clauses1:  (~a, ~c, a | b, d | ~c, ~a | ~e, ~b | ~c)
# i0 :  0
# dict1:  {b: True, c: True, d: True, a: True, e: False}
# clF:  {~c, ~b | ~c, ~a}
# clT:  {~a | ~e, d | ~c, a | b}
# dict2:  {b: True, c: True, d: True, a: True, e: False}
# vltflst:  [c, 0]
# i0 :  1
# dict1:  {b: True, c: False, d: True, a: True, e: False}
# clF:  {~a}
# clT:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# sT1:  {~a, ~a | ~e, a | b}
# costl:  [2]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [2, -1]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [2, -1, -1]
# sT1:  {~b | ~c, ~c, d | ~c, a | b}
# costl:  [2, -1, -1, 1]
# sT1:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# costl:  [2, -1, -1, 1, 0]
# dict3:  {b: [False, 2], c: [True, -1], d: [False, -1], a: [False, 1], e: [True, 0]}
# costVltf:  -1
# expon.pdf(costVltf) / t:  0.0
# rand:  0.6320874253302251
# i0 :  2
# dict1:  {b: False, c: True, d: False, a: False, e: True}
# clF:  {~c, d | ~c, a | b}
# clT:  {~b | ~c, ~a | ~e, ~a}
# dict2:  {b: False, c: True, d: False, a: False, e: True}
# dict2:  {b: False, c: True, d: False, a: True, e: True}
# vltflst:  [b, 0]
# vltflst:  [b, 0, a, 0]
# i0 :  3
# dict1:  {b: True, c: True, d: False, a: True, e: True}
# clF:  {~b | ~c, ~c, ~a, ~a | ~e, d | ~c}
# clT:  {a | b}
# dict2:  {b: True, c: True, d: False, a: True, e: True}
# dict2:  {b: True, c: False, d: False, a: True, e: True}
# vltflst:  [c, 0]
# vltflst:  [c, 0, d, 0]
# i0 :  4
# dict1:  {b: True, c: False, d: True, a: True, e: True}
# clF:  {~a | ~e, ~a}
# clT:  {~b | ~c, ~c, d | ~c, a | b}
# dict2:  {b: True, c: False, d: True, a: True, e: True}
# vltflst:  [a, 0]
# i0 :  5
# dict1:  {b: True, c: False, d: True, a: False, e: True}
# clF:  set()
# clT:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# The formula is satisfied
# anw:  {b: True, c: False, d: True, a: False, e: True}
# nsat:  [{b: True, c: False, d: True, a: False, e: True}, {b: True, c: False, d: True, a: False, e: True}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: False, a: False, e: True}, {b: True, c: False, d: False, a: False, e: True}, {b: True, c: False, d: False, a: False, e: True}, {b: True, c: False, d: False, a: False, e: True}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: True, a: False, e: True}]
# clauses1:  (~a, ~c, a | b, d | ~c, ~a | ~e, ~b | ~c)
# i0 :  0
# dict1:  {b: False, c: False, d: False, a: False, e: True}
# clF:  {a | b}
# clT:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# dict2:  {b: False, c: False, d: False, a: False, e: True}
# dict2:  {b: False, c: False, d: False, a: True, e: True}
# vltflst:  [b, 0]
# vltflst:  [b, 0, a, 0]
# i0 :  1
# dict1:  {b: True, c: False, d: False, a: True, e: True}
# clF:  {~a | ~e, ~a}
# clT:  {~b | ~c, ~c, d | ~c, a | b}
# dict2:  {b: True, c: False, d: False, a: True, e: True}
# vltflst:  [a, 0]
# i0 :  2
# dict1:  {b: True, c: False, d: False, a: False, e: True}
# clF:  set()
# clT:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# The formula is satisfied
# anw:  {b: True, c: False, d: False, a: False, e: True}
# nsat:  [{b: True, c: False, d: True, a: False, e: True}, {b: True, c: False, d: True, a: False, e: True}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: False, a: False, e: True}, {b: True, c: False, d: False, a: False, e: True}, {b: True, c: False, d: False, a: False, e: True}, {b: True, c: False, d: False, a: False, e: True}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: True, a: False, e: True}, {b: True, c: False, d: False, a: False, e: True}]
# nsat:  [{b: True, c: False, d: True, a: False, e: True}, {b: True, c: False, d: True, a: False, e: True}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: False, a: False, e: True}, {b: True, c: False, d: False, a: False, e: True}, {b: True, c: False, d: False, a: False, e: True}, {b: True, c: False, d: False, a: False, e: True}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: True, a: False, e: True}, {b: True, c: False, d: False, a: False, e: True}]
# nsatSet:  [{b: True, c: False, d: True, a: False, e: True}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: False, a: False, e: True}]
# pickvarF:  [b, c, d, a, e]
# x:  b
# sat:  {b: True, c: False, d: True, a: False, e: True}
# x1:  True
# sat:  {b: True, c: False, d: False, a: False, e: False}
# x1:  True
# sat:  {b: True, c: False, d: True, a: False, e: False}
# x1:  True
# sat:  {b: True, c: False, d: False, a: False, e: True}
# x1:  True
# nt:  4.0
# mxt: [1.0]
# x:  c
# sat:  {b: True, c: False, d: True, a: False, e: True}
# x1:  False
# sat:  {b: True, c: False, d: False, a: False, e: False}
# x1:  False
# sat:  {b: True, c: False, d: True, a: False, e: False}
# x1:  False
# sat:  {b: True, c: False, d: False, a: False, e: True}
# x1:  False
# mxf: [1.0, 1.0]
# x:  d
# sat:  {b: True, c: False, d: True, a: False, e: True}
# x1:  True
# sat:  {b: True, c: False, d: False, a: False, e: False}
# x1:  False
# sat:  {b: True, c: False, d: True, a: False, e: False}
# x1:  True
# sat:  {b: True, c: False, d: False, a: False, e: True}
# x1:  False
# mxf: [1.0, 1.0, 2.0]
# x:  a
# sat:  {b: True, c: False, d: True, a: False, e: True}
# x1:  False
# sat:  {b: True, c: False, d: False, a: False, e: False}
# x1:  False
# sat:  {b: True, c: False, d: True, a: False, e: False}
# x1:  False
# sat:  {b: True, c: False, d: False, a: False, e: True}
# x1:  False
# mxf: [1.0, 1.0, 2.0, 1.0]
# x:  e
# sat:  {b: True, c: False, d: True, a: False, e: True}
# x1:  True
# sat:  {b: True, c: False, d: False, a: False, e: False}
# x1:  False
# sat:  {b: True, c: False, d: True, a: False, e: False}
# x1:  False
# sat:  {b: True, c: False, d: False, a: False, e: True}
# x1:  True
# mxf: [1.0, 1.0, 2.0, 1.0, 2.0]
# result: 4.0

# %% [markdown]
# list of websites that I used:
#
# https://docs.sympy.org/latest/modules/logic.html
#
# https://docs.sympy.org/latest/modules/logic.html#simplification-and-equivalence-testing
#
# https://docs.sympy.org/latest/modules/parsing.html
#
# https://docs.sympy.org/latest/modules/core.html
#
# https://docs.python.org/3.7/tutorial/errors.html#tut-handling
#
# https://www.w3schools.com/python/python_howto_remove_duplicates.asp
