# %%
from sympy import *
import random
import sys
import numpy as np
import itertools
from scipy.stats import expon

# %%
# Preprocessing level for recognizing clauses in formulas of CNForm and literals as variables

input = "  (~a | b) & (~b | ~c) & (~c) & (~a) & (~b) "
input = " (~a) & (b | a) & (~c | ~b) & (~c) & (~c | d) & (~e | ~a )  "
def preprocess(input):
  """ 
   The output is a tuple with three returns inside the first one a list of literals, the second one the tuple of cluases and
   third one is the formula itself sympified
  """
  input = sympify(input, evaluate=False)
  literals = input.atoms()
  clause = []
  clause.append(clauses(input))
  return literals, clause[0], input 

def clauses(input):    # for CNFs only
  input = sympify(input, evaluate=False)
  if not isinstance(input, And):
      return input,
  return sympify(input.args)

print(clauses(input))

#print(clauses(input))
#print(type(clauses(input)))
#print(preprocess(input)[0])
#print(type(preprocess(input)[1]))
# Out:
# (~a, ~c, a | b, d | ~c, ~a | ~e, ~b | ~c)

# %%
# Preprocessing level for recognizing clauses in formulas of CNForm and literals as variables
input = " (~a) & (b | a) & (~c | ~b) & (~c) & (~c | d) & (~e | ~a )  "
class Preprocess():
    """ 
    The output is a tuple with three returns inside the first one a list of literals, the second one the tuple of clauses and
    third one is the formula itself sympified
    """
    # for CNFs only
    def __init__(self, input):
        self.input = sympify(input, evaluate=False)
        self.literals = self.input.atoms() 
        self.clauses = set(self.input.args)

print(type(Preprocess(input).clauses))
print(type(Preprocess(input).literals))
print(type(Preprocess(input).input))
# Out:
# <class 'set'>
# <class 'set'>
# And

# %%
def decision(probability = 0.5):
    return random.random() < probability

# %%
class SampleSat():
    Label = "SampleSat Algorithm"
    def __init__(self, input):
        self.input = sympify(input, evaluate=False)
        self.literals = input.atoms() 
        self.cluses = sympify(self.input.args) 
        self.falseclauses = set()
        self.trueCluses = set()
        self.dictionary = {}

# %%
#"  (~a | b) & (~b | ~c) & (~c) & (~a) "

def ChooseVar(sT, clF, dict1):
  clF = clF
  cho1 = random.choice(list(clF))
  sT = sT
  dict2 = dict1
  sT1 = set()
  dict3 = dict2.copy()
  dict4 = dict2.copy()
  bvl = []
  ##### Break value calculation
  for lit in cho1.atoms():
    print("dict2: ",dict2)
    dict2[lit] = not dict2[lit]
    vars = list(preprocess(input)[0])
    clauses1 = clauses(sT)
    dict1 = dict2
    sat = []
    clauses1 = set(clauses1)
    clF =  set()     # The set that we put the clauses that are still false inside
    clT = clauses1.copy()
    vltf = str()
    for clause in clauses1:   
      temp = clause
      #print("clause before: ", clause)
      for key in dict1.keys():
        clT = set(clT)
        if key in clause.atoms():
          clause = clause.subs({key: dict1[key]})
          #print("clause after: ", clause)              # Adding false clauses to the set
        if not clause:
          clF.add(temp)
        if temp in clF:
          clT.remove(temp)
    #prw1 = PRW(sT, dict2)
    #sT1 = prw1[1]
    #sat = prw1[4]
    #print("sat: ", sat)
    #print("sT1: ",sT1)
    bv = len(sT1) - len(clT)
    bvl.append(max(0, bv))
    dict3.update({lit: [not dict2[lit], max(0, bv)]})
  #####
  #print("dict3",dict3)
  #print("bvl",bvl)
  # chooseVar 
  vltflst = []      # value to flip list 
  probability= 0.5  ##### q probability  
  for key, value in dict3.items():
    if not type(value) == bool :
      if value[1] == 0 :          # if break value equal 0 chose the variable
        vltflst.extend([key, value[1]])
        print("vltflst: ", vltflst)
        vltf = key              # value to flip 
    else :
      #print("we shouldn't print this")
      if decision(probability):               # with probability of q chose randomly between the vars in cho1
        #print("we shouldn't print this1")
        vltf = random.sample(cho1.atoms(), 1)[0]
      else:                                   # with probability 1-q chose the min of break values in among the literals
        try:
          vltf = vltflst[vltflst.index(min(vltflst))-1]      
          #print("we shouldn't print this2")
        except ValueError:
          pass
        except TypeError:
          pass
  return vltf

# %%
def Metropolis(sT, dict1, T = 1):
  t = T
  sT = sT
  vars = list(preprocess(input)[0])
  dict1 = dict1
  costl = []
  #if len(dict1) == 0:
  for atom in vars:   # Randomly initilizing the vars to T and F
    dict1[atom] = random.choice([True, False])
      #dict1[atom]= True  # for testing
  dict2 = dict1.copy()
  dict3 = dict2.copy()
  #==============================================================================================================
  ##### Cost calculation
  for lit in vars:
    #print("dict2: ",dict2)
    dict2[lit] = not dict2[lit]
    vars = list(preprocess(input)[0])
    clauses1 = clauses(sT)
    dict1 = dict2
    sat = []
    clauses1 = set(clauses1)
    clF =  set()     # The set that we put the clauses that are still false inside
    clT = clauses1.copy()
    vltf = str()
    clauses1 = clauses(input)
    clauses1 = set(clauses1)
    dict1 = dict2.copy()
    clf =  set()     
    clt = clauses1.copy()
    for clause in clauses1:   
      temp = clause
      #print("clause before: ", clause)
      for key in dict1.keys():
        clt = set(clt)
        if key in clause.atoms():
          clause = clause.subs({key: dict1[key]})
            # Adding false clauses to the set
        if not clause:
          clf.add(temp)
      if temp in clf:
        clt.remove(temp)
    sT1 = clt
    print("sT1: ", sT1)
    bv = len(sT) - len(sT1)
    costl.append(bv)
    print("costl: ", costl)
    dict3.update({lit: [not dict2[lit], bv]}) 
  print("dict3: ",dict3)
  ######==========================================================
  vltf = random.choice(vars)
  costVltf = dict3[vltf][1]
  print("costVltf: ", costVltf)
  ex = expon.pdf(costVltf) / t
  print("expon.pdf(costVltf) / t: ", ex)
  rand = random.random()
  print("rand: ", rand)
  if costVltf <= 0:
    return [vltf, True]
  elif rand  < ex:
    return [vltf , True]
  else:
    return [vltf , not vltf]
prw = PRW(input)
Metropolis(prw[1], dict1=prw[3] )
# Out:
# clauses1:  (~a, ~c, a | b, d | ~c, ~a | ~e, ~b | ~c)
# i0 :  0
# dict1:  {b: True, c: False, d: False, a: False, e: True}
# clF:  set()
# clT:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# The formula is satisfied
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [0]
# sT1:  {~a, ~a | ~e, d | ~c, a | b}
# costl:  [0, 2]
# sT1:  {~a, ~a | ~e, a | b}
# costl:  [0, 2, 3]
# sT1:  {~a | ~e, a | b}
# costl:  [0, 2, 3, 4]
# sT1:  {a | b}
# costl:  [0, 2, 3, 4, 5]
# dict3:  {b: [False, 0], c: [False, 2], d: [True, 3], a: [False, 4], e: [False, 5]}
# costVltf:  5
# expon.pdf(costVltf) / t:  0.006737946999085467
# rand:  0.542442180172715
# [e, False]

# %%
def PRW(input, dt = {}, P = 0.5, T = 1):  # Returns the set of false clauses, set of truth clauses, the clause chosen at random from False cluases
                  # Also returns formula is satisfied when there is no false clauses and the dict of assigned values to vars
  p = P
  t = T
  vars = list(preprocess(input)[0])
  clauses1 = clauses(input)
  dict1 = dt
  isat = 0
  sat = []
  if True:#len(dict1) == 0:
    for atom in vars:   # Randomly initilizing the vars to T and F
      dict1[atom] = random.choice([True, False])
      #dict1[atom]= True  # for testing
  print("clauses1: ",clauses1)
  clauses1 = list(clauses1)
  clF =  set()     # The set that we put the clauses that are still false inside
  clT = clauses1.copy()
  vltf = str()
  i0 =0
  while i0 in range(0,1000):
    print("i0 : ", i0)
    print("dict1: ", dict1)
    i0 += 1
    if len(clF) != 0:
      if vltf[0] in dict1 & vltf[1]:
        dict1[vltf[0]] = not dict1[vltf[0]]
    for clause in clauses1:   
      temp = clause
      #print("clause before: ", clause)
      for key in dict1.keys():
        clT = set(clT)
        if key in clause.atoms():
          clause = clause.subs({key: dict1[key]})
          #print("clause after: ", clause)              # Adding false clauses to the set
        if not clause:
          clF.add(temp)
      if temp in clF:
        clT.remove(temp)
    print("clF: ", clF)
    print("clT: ", clT)
    if len(clF) == 0:
      sat.append(dict1)
      #print("dict1: ", dict1)
      print("The formula is satisfied") 
      break
    if len(clF) != 0:
      if decision(p):
        vltf = ChooseVar(clT, clF, dict1)
      else: 
        vltf = Metropolis(clT, dict1 , T = t)
      clF = set()      # The set that we put the clauses that are still false inside
      clT = clauses1.copy()
  return clF, clT, 0, dict1, sat
     


prw = PRW(input)
print("PRW: ",prw)
#print("prw[1] :",prw[1])
#print(PRW(prw[1],prw[3]))
# Out:
# clauses1:  (~a, ~c, a | b, d | ~c, ~a | ~e, ~b | ~c)
# i0 :  0
# dict1:  {b: False, c: True, d: False, a: False, e: True}
# clF:  {~c, d | ~c, a | b}
# clT:  {~b | ~c, ~a | ~e, ~a}
# sT1:  {~b | ~c, ~c, d | ~c, a | b}
# costl:  [-1]
# sT1:  {a | b}
# costl:  [-1, 2]
# sT1:  {d | ~c, a | b}
# costl:  [-1, 2, 1]
# sT1:  {~a, ~a | ~e, d | ~c, a | b}
# costl:  [-1, 2, 1, -1]
# sT1:  {~a, ~a | ~e, d | ~c, a | b}
# costl:  [-1, 2, 1, -1, -1]
# dict3:  {b: [False, -1], c: [False, 2], d: [False, 1], a: [True, -1], e: [True, -1]}
# costVltf:  -1
# expon.pdf(costVltf) / t:  0.0
# rand:  0.8222452596253537
# i0 :  1
# dict1:  {b: False, c: False, d: False, a: True, e: True}
# clF:  {~a | ~e, ~a}
# clT:  {~b | ~c, ~c, d | ~c, a | b}
# dict2:  {b: False, c: False, d: False, a: True, e: True}
# vltflst:  [a, 0]
# i0 :  2
# dict1:  {b: False, c: False, d: False, a: False, e: True}
# clF:  {a | b}
# clT:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# sT1:  {~b | ~c, ~a | ~e, d | ~c, ~a}
# costl:  [1]
# sT1:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# costl:  [1, 0]
# sT1:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# costl:  [1, 0, 0]
# sT1:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# costl:  [1, 0, 0, 0]
# sT1:  {~b | ~c, ~c, d | ~c, a | b}
# costl:  [1, 0, 0, 0, 1]
# dict3:  {b: [True, 1], c: [True, 0], d: [True, 0], a: [False, 0], e: [False, 1]}
# costVltf:  1
# expon.pdf(costVltf) / t:  0.36787944117144233
# rand:  0.584922119929257
# i0 :  3
# dict1:  {b: True, c: True, d: True, a: False, e: False}
# clF:  {~c, ~b | ~c}
# clT:  {~a | ~e, a | b, ~a, d | ~c}
# dict2:  {b: True, c: True, d: True, a: False, e: False}
# dict2:  {b: True, c: False, d: True, a: False, e: False}
# vltflst:  [b, 0]
# vltflst:  [b, 0, c, 0]
# i0 :  4
# dict1:  {b: False, c: False, d: True, a: False, e: False}
# clF:  {a | b}
# clT:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# sT1:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# costl:  [0]
# sT1:  {~a | ~e, a | b, d | ~c}
# costl:  [0, 2]
# sT1:  {~a | ~e, a | b}
# costl:  [0, 2, 3]
# sT1:  {~a, ~a | ~e, a | b}
# costl:  [0, 2, 3, 2]
# sT1:  {~a, ~a | ~e, a | b}
# costl:  [0, 2, 3, 2, 2]
# dict3:  {b: [False, 0], c: [False, 2], d: [True, 3], a: [True, 2], e: [False, 2]}
# costVltf:  2
# expon.pdf(costVltf) / t:  0.1353352832366127
# rand:  0.07758282088645829
# i0 :  5
# dict1:  {b: False, c: False, d: True, a: True, e: False}
# clF:  {~a}
# clT:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# sT1:  {~b | ~c, ~c, d | ~c, a | b}
# costl:  [1]
# sT1:  {~b | ~c, a | b}
# costl:  [1, 3]
# sT1:  {~b | ~c, a | b, d | ~c}
# costl:  [1, 3, 2]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, ~a}
# costl:  [1, 3, 2, 1]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, ~a}
# costl:  [1, 3, 2, 1, 1]
# dict3:  {b: [True, 1], c: [False, 3], d: [False, 2], a: [True, 1], e: [True, 1]}
# costVltf:  1
# expon.pdf(costVltf) / t:  0.36787944117144233
# rand:  0.8565129375903255
# i0 :  6
# dict1:  {b: True, c: False, d: False, a: True, e: True}
# clF:  {~a | ~e, ~a}
# clT:  {~b | ~c, ~c, d | ~c, a | b}
# sT1:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# costl:  [-1]
# sT1:  {~a | ~e, a | b, d | ~c}
# costl:  [-1, 1]
# sT1:  {~a | ~e, a | b}
# costl:  [-1, 1, 2]
# sT1:  {~a, ~a | ~e, a | b}
# costl:  [-1, 1, 2, 1]
# sT1:  {~a, ~a | ~e, a | b}
# costl:  [-1, 1, 2, 1, 1]
# dict3:  {b: [False, -1], c: [False, 1], d: [True, 2], a: [True, 1], e: [False, 1]}
# costVltf:  1
# expon.pdf(costVltf) / t:  0.36787944117144233
# rand:  0.026114056419145548
# i0 :  7
# dict1:  {b: False, c: False, d: True, a: True, e: False}
# clF:  {~a}
# clT:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# sT1:  {~b | ~c, ~a | ~e, ~a}
# costl:  [2]
# sT1:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# costl:  [2, 0]
# sT1:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# costl:  [2, 0, 0]
# sT1:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# costl:  [2, 0, 0, 0]
# sT1:  {~b | ~c, ~c, d | ~c, a | b}
# costl:  [2, 0, 0, 0, 1]
# dict3:  {b: [True, 2], c: [True, 0], d: [False, 0], a: [False, 0], e: [False, 1]}
# costVltf:  0
# expon.pdf(costVltf) / t:  1.0
# rand:  0.4941496656884836
# i0 :  8
# dict1:  {b: True, c: True, d: False, a: False, e: False}
# clF:  {~c, ~b | ~c, d | ~c}
# clT:  {~a, ~a | ~e, a | b}
# dict2:  {b: True, c: True, d: False, a: False, e: False}
# vltflst:  [c, 0]
# i0 :  9
# dict1:  {b: True, c: False, d: False, a: False, e: False}
# clF:  set()
# clT:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# The formula is satisfied
# PRW:  (set(), {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}, 0, {b: True, c: False, d: False, a: False, e: False}, [{b: True, c: False, d: False, a: False, e: False}])

# %%
def unitprop(input, literal):
  vars = list(preprocess(input)[0])
  output = []
  for var in vars:
    if literal != var:
      output.append(var)  
  print("output:", output)
  return output
vars = list(preprocess(input)[0])
print("vars: ", vars)
#print("lit: ", lit)
#unitprop(input, lit)
# Out:
# vars:  [b, c, d, a, e]

# %%
## ApproxCount Algorithm
k = 5
nsat = []
nsatSet = []
inputSet = Preprocess(input)
#==============
# constructiong solution space of
for i in range(0,20):   # 
  anw = PRW(input)[3]
  anw1 = anw.copy()
  print("anw: ", anw1)
  #anw = prw[4]
  nsat.append(anw1)
  print("nsat: ", nsat)
  ##  Dropping duplicates in the nsat list 
  if anw1 not in nsatSet:   
    nsatSet.append(anw1)
  if len(nsatSet) == k:
    break 

print("nsat: ", nsat)
print("nsatSet: ", nsatSet)
k = len(nsatSet)
mx = []
pickvarF = list(inputSet.literals)
print("pickvarF: ", pickvarF)

for x in pickvarF:
    print("x: ", x)
    nf = 0.0
    nt = 0.0
    for sat in nsatSet:
        print("sat: ", sat)
        dic = sat
        x1 = dic[x]
        print("x1: ", x1)
        if x1 == True:
            nt += 1.0  
        if x1 == False:
            nf += 1.0 
    if nt > nf:
        ## unitprop F
        #pickvarF = unitprop(pickvarF, x)
        print("nt: ", nt)
        temp = k/nt
        mx.append(temp)
        print("mxt:", mx)
    else:
        ### unitprop F
        #pickvarF = unitprop(pickvarF, x)
        temp = k/nf
        mx.append(temp)
        print("mxf:", mx)

result = np.prod(mx) 
print("result:", result)
# Out:
# clauses1:  (~a, ~c, a | b, d | ~c, ~a | ~e, ~b | ~c)
# i0 :  0
# dict1:  {b: False, c: False, d: False, a: False, e: False}
# clF:  {a | b}
# clT:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [-1]
# sT1:  {~a, ~a | ~e, d | ~c, a | b}
# costl:  [-1, 1]
# sT1:  {~a, ~a | ~e, a | b}
# costl:  [-1, 1, 2]
# sT1:  {a | b}
# costl:  [-1, 1, 2, 4]
# sT1:  {~a | ~e, a | b}
# costl:  [-1, 1, 2, 4, 3]
# dict3:  {b: [False, -1], c: [False, 1], d: [True, 2], a: [False, 4], e: [True, 3]}
# costVltf:  1
# expon.pdf(costVltf) / t:  0.36787944117144233
# rand:  0.19913685405631276
# i0 :  1
# dict1:  {b: False, c: False, d: True, a: False, e: True}
# clF:  {a | b}
# clT:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# dict2:  {b: False, c: False, d: True, a: False, e: True}
# dict2:  {b: False, c: False, d: True, a: True, e: True}
# vltflst:  [b, 0]
# vltflst:  [b, 0, a, 0]
# i0 :  2
# dict1:  {b: True, c: False, d: True, a: True, e: True}
# clF:  {~a | ~e, ~a}
# clT:  {~b | ~c, ~c, d | ~c, a | b}
# dict2:  {b: True, c: False, d: True, a: True, e: True}
# dict2:  {b: True, c: False, d: True, a: False, e: True}
# vltflst:  [a, 0]
# vltflst:  [a, 0, e, 0]
# i0 :  3
# dict1:  {b: True, c: False, d: True, a: False, e: False}
# clF:  set()
# clT:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# The formula is satisfied
# anw:  {b: True, c: False, d: True, a: False, e: False}
# nsat:  [{b: True, c: False, d: True, a: False, e: False}]
# clauses1:  (~a, ~c, a | b, d | ~c, ~a | ~e, ~b | ~c)
# i0 :  0
# dict1:  {b: True, c: False, d: False, a: False, e: True}
# clF:  set()
# clT:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# The formula is satisfied
# anw:  {b: True, c: False, d: False, a: False, e: True}
# nsat:  [{b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: False, a: False, e: True}]
# clauses1:  (~a, ~c, a | b, d | ~c, ~a | ~e, ~b | ~c)
# i0 :  0
# dict1:  {b: False, c: True, d: False, a: True, e: False}
# clF:  {~c, d | ~c, ~a}
# clT:  {~b | ~c, ~a | ~e, a | b}
# sT1:  {~a, ~a | ~e, d | ~c, a | b}
# costl:  [-1]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [-1, -3]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [-1, -3, -3]
# sT1:  {~b | ~c, ~c, d | ~c, a | b}
# costl:  [-1, -3, -3, -1]
# sT1:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# costl:  [-1, -3, -3, -1, -2]
# dict3:  {b: [False, -1], c: [True, -3], d: [True, -3], a: [False, -1], e: [True, -2]}
# costVltf:  -1
# expon.pdf(costVltf) / t:  0.0
# rand:  0.9037863108098484
# i0 :  1
# dict1:  {b: False, c: True, d: True, a: False, e: True}
# clF:  {~c, a | b}
# clT:  {~b | ~c, ~a | ~e, d | ~c, ~a}
# sT1:  {~a, ~a | ~e, d | ~c, a | b}
# costl:  [0]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [0, -2]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [0, -2, -2]
# sT1:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# costl:  [0, -2, -2, -1]
# sT1:  {~b | ~c, ~c, d | ~c, a | b}
# costl:  [0, -2, -2, -1, 0]
# dict3:  {b: [False, 0], c: [True, -2], d: [True, -2], a: [False, -1], e: [False, 0]}
# costVltf:  0
# expon.pdf(costVltf) / t:  1.0
# rand:  0.35688819835592234
# i0 :  2
# dict1:  {b: False, c: True, d: True, a: False, e: False}
# clF:  {~c, a | b}
# clT:  {~b | ~c, ~a | ~e, d | ~c, ~a}
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [-2]
# sT1:  {~a, ~a | ~e, d | ~c, a | b}
# costl:  [-2, 0]
# sT1:  {~a, ~a | ~e, a | b}
# costl:  [-2, 0, 1]
# sT1:  {~a | ~e, a | b}
# costl:  [-2, 0, 1, 2]
# sT1:  {a | b}
# costl:  [-2, 0, 1, 2, 3]
# dict3:  {b: [False, -2], c: [False, 0], d: [True, 1], a: [False, 2], e: [False, 3]}
# costVltf:  3
# expon.pdf(costVltf) / t:  0.049787068367863944
# rand:  0.5552702850436751
# i0 :  3
# dict1:  {b: False, c: False, d: True, a: False, e: False}
# clF:  {a | b}
# clT:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# dict2:  {b: False, c: False, d: True, a: False, e: False}
# dict2:  {b: False, c: False, d: True, a: True, e: False}
# vltflst:  [b, 0]
# vltflst:  [b, 0, a, 0]
# i0 :  4
# dict1:  {b: True, c: False, d: True, a: True, e: False}
# clF:  {~a}
# clT:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# dict2:  {b: True, c: False, d: True, a: True, e: False}
# vltflst:  [a, 0]
# i0 :  5
# dict1:  {b: True, c: False, d: True, a: False, e: False}
# clF:  set()
# clT:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# The formula is satisfied
# anw:  {b: True, c: False, d: True, a: False, e: False}
# nsat:  [{b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: False, a: False, e: True}, {b: True, c: False, d: True, a: False, e: False}]
# clauses1:  (~a, ~c, a | b, d | ~c, ~a | ~e, ~b | ~c)
# i0 :  0
# dict1:  {b: False, c: False, d: False, a: False, e: False}
# clF:  {a | b}
# clT:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# sT1:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# costl:  [0]
# sT1:  {~a | ~e, a | b, d | ~c}
# costl:  [0, 2]
# sT1:  {~a | ~e, a | b}
# costl:  [0, 2, 3]
# sT1:  {~a, ~a | ~e, a | b}
# costl:  [0, 2, 3, 2]
# sT1:  {~a, ~a | ~e, a | b}
# costl:  [0, 2, 3, 2, 2]
# dict3:  {b: [False, 0], c: [False, 2], d: [True, 3], a: [True, 2], e: [False, 2]}
# costVltf:  2
# expon.pdf(costVltf) / t:  0.1353352832366127
# rand:  0.46884494112137953
# i0 :  1
# dict1:  {b: False, c: False, d: True, a: True, e: False}
# clF:  {~a}
# clT:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# dict2:  {b: False, c: False, d: True, a: True, e: False}
# vltflst:  [a, 0]
# i0 :  2
# dict1:  {b: False, c: False, d: True, a: False, e: False}
# clF:  {a | b}
# clT:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# sT1:  {a | b}
# costl:  [4]
# sT1:  {~b | ~c, ~c, d | ~c, a | b}
# costl:  [4, 1]
# sT1:  {~b | ~c, ~c, d | ~c, a | b}
# costl:  [4, 1, 1]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [4, 1, 1, -1]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [4, 1, 1, -1, -1]
# dict3:  {b: [False, 4], c: [True, 1], d: [False, 1], a: [True, -1], e: [True, -1]}
# costVltf:  1
# expon.pdf(costVltf) / t:  0.36787944117144233
# rand:  0.6937704654111007
# i0 :  3
# dict1:  {b: False, c: True, d: False, a: True, e: True}
# clF:  {~c, ~a | ~e, d | ~c, ~a}
# clT:  {~b | ~c, a | b}
# dict2:  {b: False, c: True, d: False, a: True, e: True}
# dict2:  {b: False, c: True, d: False, a: False, e: True}
# vltflst:  [a, 0]
# vltflst:  [a, 0, e, 0]
# i0 :  4
# dict1:  {b: False, c: True, d: False, a: False, e: False}
# clF:  {~c, d | ~c, a | b}
# clT:  {~b | ~c, ~a | ~e, ~a}
# sT1:  {~a | ~e, a | b, d | ~c}
# costl:  [0]
# sT1:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# costl:  [0, -2]
# sT1:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# costl:  [0, -2, -2]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [0, -2, -2, -3]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [0, -2, -2, -3, -3]
# dict3:  {b: [False, 0], c: [True, -2], d: [True, -2], a: [True, -3], e: [False, -3]}
# costVltf:  -3
# expon.pdf(costVltf) / t:  0.0
# rand:  0.33651905199632204
# i0 :  5
# dict1:  {b: False, c: True, d: True, a: True, e: False}
# clF:  {~c, ~a}
# clT:  {~b | ~c, ~a | ~e, d | ~c, a | b}
# dict2:  {b: False, c: True, d: True, a: True, e: False}
# vltflst:  [a, 0]
# i0 :  6
# dict1:  {b: False, c: True, d: True, a: False, e: False}
# clF:  {~c, a | b}
# clT:  {~b | ~c, ~a | ~e, d | ~c, ~a}
# dict2:  {b: False, c: True, d: True, a: False, e: False}
# dict2:  {b: False, c: True, d: True, a: True, e: False}
# vltflst:  [b, 0]
# vltflst:  [b, 0, a, 0]
# i0 :  7
# dict1:  {b: True, c: True, d: True, a: True, e: False}
# clF:  {~c, ~b | ~c, ~a}
# clT:  {~a | ~e, d | ~c, a | b}
# sT1:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# costl:  [-2]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, ~a}
# costl:  [-2, -1]
# sT1:  {~b | ~c, ~a | ~e, ~a}
# costl:  [-2, -1, 0]
# sT1:  {~b | ~c, ~a | ~e, a | b}
# costl:  [-2, -1, 0, 0]
# sT1:  {~b | ~c, a | b}
# costl:  [-2, -1, 0, 0, 1]
# dict3:  {b: [True, -2], c: [False, -1], d: [True, 0], a: [False, 0], e: [False, 1]}
# costVltf:  0
# expon.pdf(costVltf) / t:  1.0
# rand:  0.056603574461070005
# i0 :  8
# dict1:  {b: True, c: False, d: True, a: False, e: False}
# clF:  set()
# clT:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# The formula is satisfied
# anw:  {b: True, c: False, d: True, a: False, e: False}
# nsat:  [{b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: False, a: False, e: True}, {b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: True, a: False, e: False}]
# clauses1:  (~a, ~c, a | b, d | ~c, ~a | ~e, ~b | ~c)
# i0 :  0
# dict1:  {b: False, c: False, d: True, a: True, e: True}
# clF:  {~a | ~e, ~a}
# clT:  {~b | ~c, ~c, d | ~c, a | b}
# dict2:  {b: False, c: False, d: True, a: True, e: True}
# vltflst:  [a, 0]
# i0 :  1
# dict1:  {b: False, c: False, d: True, a: False, e: True}
# clF:  {a | b}
# clT:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# dict2:  {b: False, c: False, d: True, a: False, e: True}
# dict2:  {b: False, c: False, d: True, a: True, e: True}
# vltflst:  [b, 0]
# vltflst:  [b, 0, a, 0]
# i0 :  2
# dict1:  {b: True, c: False, d: True, a: True, e: True}
# clF:  {~a | ~e, ~a}
# clT:  {~b | ~c, ~c, d | ~c, a | b}
# sT1:  {~b | ~c, ~c, d | ~c, a | b}
# costl:  [0]
# sT1:  {~b | ~c, a | b, d | ~c}
# costl:  [0, 1]
# sT1:  {~b | ~c, a | b}
# costl:  [0, 1, 2]
# sT1:  {~b | ~c, ~a | ~e, ~a}
# costl:  [0, 1, 2, 1]
# sT1:  {~b | ~c, ~a | ~e, ~a}
# costl:  [0, 1, 2, 1, 1]
# dict3:  {b: [True, 0], c: [False, 1], d: [True, 2], a: [True, 1], e: [True, 1]}
# costVltf:  1
# expon.pdf(costVltf) / t:  0.36787944117144233
# rand:  0.03252833561999846
# i0 :  3
# dict1:  {b: True, c: False, d: True, a: True, e: True}
# clF:  {~a | ~e, ~a}
# clT:  {~b | ~c, ~c, d | ~c, a | b}
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [-2]
# sT1:  {~a, ~a | ~e, a | b}
# costl:  [-2, 1]
# sT1:  {~a, ~a | ~e, d | ~c, a | b}
# costl:  [-2, 1, 0]
# sT1:  {d | ~c, a | b}
# costl:  [-2, 1, 0, 2]
# sT1:  {~a | ~e, a | b, d | ~c}
# costl:  [-2, 1, 0, 2, 1]
# dict3:  {b: [False, -2], c: [False, 1], d: [False, 0], a: [False, 2], e: [True, 1]}
# costVltf:  -2
# expon.pdf(costVltf) / t:  0.0
# rand:  0.8211999673941272
# i0 :  4
# dict1:  {b: False, c: False, d: False, a: False, e: True}
# clF:  {a | b}
# clT:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# dict2:  {b: False, c: False, d: False, a: False, e: True}
# dict2:  {b: False, c: False, d: False, a: True, e: True}
# vltflst:  [b, 0]
# vltflst:  [b, 0, a, 0]
# i0 :  5
# dict1:  {b: True, c: False, d: False, a: True, e: True}
# clF:  {~a | ~e, ~a}
# clT:  {~b | ~c, ~c, d | ~c, a | b}
# dict2:  {b: True, c: False, d: False, a: True, e: True}
# dict2:  {b: True, c: False, d: False, a: False, e: True}
# vltflst:  [a, 0]
# vltflst:  [a, 0, e, 0]
# i0 :  6
# dict1:  {b: True, c: False, d: False, a: False, e: False}
# clF:  set()
# clT:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# The formula is satisfied
# anw:  {b: True, c: False, d: False, a: False, e: False}
# nsat:  [{b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: False, a: False, e: True}, {b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}]
# clauses1:  (~a, ~c, a | b, d | ~c, ~a | ~e, ~b | ~c)
# i0 :  0
# dict1:  {b: False, c: True, d: True, a: False, e: False}
# clF:  {~c, a | b}
# clT:  {~b | ~c, ~a | ~e, d | ~c, ~a}
# sT1:  {~b | ~c, ~a | ~e, ~a}
# costl:  [1]
# sT1:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# costl:  [1, -1]
# sT1:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# costl:  [1, -1, -1]
# sT1:  {~b | ~c, ~c, d | ~c, a | b}
# costl:  [1, -1, -1, 0]
# sT1:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# costl:  [1, -1, -1, 0, -1]
# dict3:  {b: [True, 1], c: [True, -1], d: [False, -1], a: [False, 0], e: [True, -1]}
# costVltf:  -1
# expon.pdf(costVltf) / t:  0.0
# rand:  0.6533863376936425
# i0 :  1
# dict1:  {b: True, c: True, d: False, a: False, e: True}
# clF:  {~c, ~b | ~c, d | ~c}
# clT:  {~a, ~a | ~e, a | b}
# sT1:  {~b | ~c, ~c, d | ~c, a | b}
# costl:  [-1]
# sT1:  {~b | ~c, a | b}
# costl:  [-1, 1]
# sT1:  {~b | ~c, a | b, d | ~c}
# costl:  [-1, 1, 0]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, ~a}
# costl:  [-1, 1, 0, -1]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, ~a}
# costl:  [-1, 1, 0, -1, -1]
# dict3:  {b: [True, -1], c: [False, 1], d: [False, 0], a: [True, -1], e: [True, -1]}
# costVltf:  0
# expon.pdf(costVltf) / t:  1.0
# rand:  0.4436735713467579
# i0 :  2
# dict1:  {b: True, c: False, d: False, a: True, e: True}
# clF:  {~a | ~e, ~a}
# clT:  {~b | ~c, ~c, d | ~c, a | b}
# sT1:  {~a, ~a | ~e, a | b}
# costl:  [1]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [1, -2]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [1, -2, -2]
# sT1:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# costl:  [1, -2, -2, -1]
# sT1:  {~b | ~c, ~c, d | ~c, a | b}
# costl:  [1, -2, -2, -1, 0]
# dict3:  {b: [False, 1], c: [True, -2], d: [False, -2], a: [False, -1], e: [False, 0]}
# costVltf:  -1
# expon.pdf(costVltf) / t:  0.0
# rand:  0.0696845052279399
# i0 :  3
# dict1:  {b: False, c: True, d: False, a: False, e: False}
# clF:  {~c, d | ~c, a | b}
# clT:  {~b | ~c, ~a | ~e, ~a}
# dict2:  {b: False, c: True, d: False, a: False, e: False}
# dict2:  {b: False, c: False, d: False, a: False, e: False}
# vltflst:  [c, 0]
# vltflst:  [c, 0, d, 0]
# i0 :  4
# dict1:  {b: False, c: False, d: True, a: False, e: False}
# clF:  {a | b}
# clT:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# sT1:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# costl:  [0]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, ~a}
# costl:  [0, 1]
# sT1:  {~b | ~c, ~a | ~e, ~a}
# costl:  [0, 1, 2]
# sT1:  {~b | ~c, ~a | ~e, a | b}
# costl:  [0, 1, 2, 2]
# sT1:  {~b | ~c, a | b}
# costl:  [0, 1, 2, 2, 3]
# dict3:  {b: [True, 0], c: [False, 1], d: [True, 2], a: [False, 2], e: [False, 3]}
# costVltf:  0
# expon.pdf(costVltf) / t:  1.0
# rand:  0.4609691149594083
# i0 :  5
# dict1:  {b: True, c: False, d: True, a: False, e: False}
# clF:  set()
# clT:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# The formula is satisfied
# anw:  {b: True, c: False, d: True, a: False, e: False}
# nsat:  [{b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: False, a: False, e: True}, {b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: True, a: False, e: False}]
# clauses1:  (~a, ~c, a | b, d | ~c, ~a | ~e, ~b | ~c)
# i0 :  0
# dict1:  {b: True, c: False, d: True, a: False, e: True}
# clF:  set()
# clT:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# The formula is satisfied
# anw:  {b: True, c: False, d: True, a: False, e: True}
# nsat:  [{b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: False, a: False, e: True}, {b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: True, a: False, e: True}]
# clauses1:  (~a, ~c, a | b, d | ~c, ~a | ~e, ~b | ~c)
# i0 :  0
# dict1:  {b: True, c: False, d: False, a: False, e: True}
# clF:  set()
# clT:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# The formula is satisfied
# anw:  {b: True, c: False, d: False, a: False, e: True}
# nsat:  [{b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: False, a: False, e: True}, {b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: True, a: False, e: True}, {b: True, c: False, d: False, a: False, e: True}]
# clauses1:  (~a, ~c, a | b, d | ~c, ~a | ~e, ~b | ~c)
# i0 :  0
# dict1:  {b: False, c: False, d: True, a: True, e: False}
# clF:  {~a}
# clT:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# dict2:  {b: False, c: False, d: True, a: True, e: False}
# vltflst:  [a, 0]
# i0 :  1
# dict1:  {b: False, c: False, d: True, a: False, e: False}
# clF:  {a | b}
# clT:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# sT1:  {~b | ~c, ~a | ~e, d | ~c, ~a}
# costl:  [1]
# sT1:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# costl:  [1, 0]
# sT1:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# costl:  [1, 0, 0]
# sT1:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# costl:  [1, 0, 0, 0]
# sT1:  {~b | ~c, ~c, d | ~c, a | b}
# costl:  [1, 0, 0, 0, 1]
# dict3:  {b: [True, 1], c: [True, 0], d: [True, 0], a: [False, 0], e: [False, 1]}
# costVltf:  1
# expon.pdf(costVltf) / t:  0.36787944117144233
# rand:  0.5457394927079239
# i0 :  2
# dict1:  {b: True, c: True, d: True, a: False, e: False}
# clF:  {~c, ~b | ~c}
# clT:  {~a | ~e, a | b, ~a, d | ~c}
# sT1:  {~b | ~c, ~c, d | ~c, a | b}
# costl:  [0]
# sT1:  {~b | ~c, a | b, d | ~c}
# costl:  [0, 1]
# sT1:  {~b | ~c, a | b}
# costl:  [0, 1, 2]
# sT1:  {~b | ~c, ~a | ~e, ~a}
# costl:  [0, 1, 2, 1]
# sT1:  {~b | ~c, ~a | ~e, ~a}
# costl:  [0, 1, 2, 1, 1]
# dict3:  {b: [True, 0], c: [False, 1], d: [True, 2], a: [True, 1], e: [True, 1]}
# costVltf:  2
# expon.pdf(costVltf) / t:  0.1353352832366127
# rand:  0.5945235148066108
# i0 :  3
# dict1:  {b: True, c: False, d: True, a: True, e: True}
# clF:  {~a | ~e, ~a}
# clT:  {~b | ~c, ~c, d | ~c, a | b}
# sT1:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# costl:  [-1]
# sT1:  {~b | ~c, ~a | ~e, ~a}
# costl:  [-1, 1]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, ~a}
# costl:  [-1, 1, 0]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b}
# costl:  [-1, 1, 0, 0]
# sT1:  {~b | ~c, a | b, d | ~c}
# costl:  [-1, 1, 0, 0, 1]
# dict3:  {b: [True, -1], c: [False, 1], d: [False, 0], a: [False, 0], e: [False, 1]}
# costVltf:  0
# expon.pdf(costVltf) / t:  1.0
# rand:  0.5182540816596143
# i0 :  4
# dict1:  {b: True, c: False, d: False, a: False, e: False}
# clF:  set()
# clT:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# The formula is satisfied
# anw:  {b: True, c: False, d: False, a: False, e: False}
# nsat:  [{b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: False, a: False, e: True}, {b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: True, a: False, e: True}, {b: True, c: False, d: False, a: False, e: True}, {b: True, c: False, d: False, a: False, e: False}]
# clauses1:  (~a, ~c, a | b, d | ~c, ~a | ~e, ~b | ~c)
# i0 :  0
# dict1:  {b: False, c: False, d: False, a: False, e: False}
# clF:  {a | b}
# clT:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# dict2:  {b: False, c: False, d: False, a: False, e: False}
# dict2:  {b: False, c: False, d: False, a: True, e: False}
# vltflst:  [b, 0]
# vltflst:  [b, 0, a, 0]
# i0 :  1
# dict1:  {b: True, c: False, d: False, a: True, e: False}
# clF:  {~a}
# clT:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# sT1:  {~a | ~e, a | b}
# costl:  [3]
# sT1:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# costl:  [3, 0]
# sT1:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# costl:  [3, 0, 0]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [3, 0, 0, -1]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [3, 0, 0, -1, -1]
# dict3:  {b: [False, 3], c: [True, 0], d: [False, 0], a: [True, -1], e: [False, -1]}
# costVltf:  -1
# expon.pdf(costVltf) / t:  0.0
# rand:  0.5444389735760861
# i0 :  2
# dict1:  {b: False, c: True, d: False, a: True, e: False}
# clF:  {~c, d | ~c, ~a}
# clT:  {~b | ~c, ~a | ~e, a | b}
# dict2:  {b: False, c: True, d: False, a: True, e: False}
# vltflst:  [a, 0]
# i0 :  3
# dict1:  {b: False, c: True, d: False, a: False, e: False}
# clF:  {~c, d | ~c, a | b}
# clT:  {~b | ~c, ~a | ~e, ~a}
# sT1:  {~a | ~e, a | b, d | ~c}
# costl:  [0]
# sT1:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# costl:  [0, -2]
# sT1:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# costl:  [0, -2, -2]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [0, -2, -2, -3]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [0, -2, -2, -3, -3]
# dict3:  {b: [False, 0], c: [True, -2], d: [True, -2], a: [True, -3], e: [False, -3]}
# costVltf:  -3
# expon.pdf(costVltf) / t:  0.0
# rand:  0.30271612966865713
# i0 :  4
# dict1:  {b: False, c: True, d: True, a: True, e: False}
# clF:  {~c, ~a}
# clT:  {~b | ~c, ~a | ~e, d | ~c, a | b}
# dict2:  {b: False, c: True, d: True, a: True, e: False}
# vltflst:  [c, 0]
# i0 :  5
# dict1:  {b: False, c: False, d: True, a: True, e: False}
# clF:  {~a}
# clT:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# sT1:  {~b | ~c, ~a | ~e, ~a}
# costl:  [2]
# sT1:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# costl:  [2, 0]
# sT1:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# costl:  [2, 0, 0]
# sT1:  {~b | ~c, ~c, d | ~c, a | b}
# costl:  [2, 0, 0, 1]
# sT1:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# costl:  [2, 0, 0, 1, 0]
# dict3:  {b: [True, 2], c: [True, 0], d: [False, 0], a: [False, 1], e: [True, 0]}
# costVltf:  0
# expon.pdf(costVltf) / t:  1.0
# rand:  0.9119881515684324
# i0 :  6
# dict1:  {b: True, c: True, d: False, a: False, e: True}
# clF:  {~c, ~b | ~c, d | ~c}
# clT:  {~a, ~a | ~e, a | b}
# sT1:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# costl:  [-2]
# sT1:  {~b | ~c, ~a | ~e, ~a}
# costl:  [-2, 0]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, ~a}
# costl:  [-2, 0, -1]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b}
# costl:  [-2, 0, -1, -1]
# sT1:  {~b | ~c, a | b, d | ~c}
# costl:  [-2, 0, -1, -1, 0]
# dict3:  {b: [True, -2], c: [False, 0], d: [False, -1], a: [False, -1], e: [False, 0]}
# costVltf:  0
# expon.pdf(costVltf) / t:  1.0
# rand:  0.591058512210828
# i0 :  7
# dict1:  {b: True, c: False, d: False, a: False, e: False}
# clF:  set()
# clT:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# The formula is satisfied
# anw:  {b: True, c: False, d: False, a: False, e: False}
# nsat:  [{b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: False, a: False, e: True}, {b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: True, a: False, e: True}, {b: True, c: False, d: False, a: False, e: True}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}]
# clauses1:  (~a, ~c, a | b, d | ~c, ~a | ~e, ~b | ~c)
# i0 :  0
# dict1:  {b: False, c: False, d: False, a: True, e: False}
# clF:  {~a}
# clT:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# dict2:  {b: False, c: False, d: False, a: True, e: False}
# vltflst:  [a, 0]
# i0 :  1
# dict1:  {b: False, c: False, d: False, a: False, e: False}
# clF:  {a | b}
# clT:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# dict2:  {b: False, c: False, d: False, a: False, e: False}
# dict2:  {b: False, c: False, d: False, a: True, e: False}
# vltflst:  [b, 0]
# vltflst:  [b, 0, a, 0]
# i0 :  2
# dict1:  {b: True, c: False, d: False, a: True, e: False}
# clF:  {~a}
# clT:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# sT1:  {~b | ~c, ~a | ~e, ~a}
# costl:  [2]
# sT1:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# costl:  [2, 0]
# sT1:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# costl:  [2, 0, 0]
# sT1:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# costl:  [2, 0, 0, 0]
# sT1:  {~b | ~c, ~c, d | ~c, a | b}
# costl:  [2, 0, 0, 0, 1]
# dict3:  {b: [True, 2], c: [True, 0], d: [False, 0], a: [False, 0], e: [False, 1]}
# costVltf:  0
# expon.pdf(costVltf) / t:  1.0
# rand:  0.8990444568584689
# i0 :  3
# dict1:  {b: True, c: True, d: False, a: False, e: False}
# clF:  {~c, ~b | ~c, d | ~c}
# clT:  {~a, ~a | ~e, a | b}
# sT1:  {~b | ~c, ~c, d | ~c, a | b}
# costl:  [-1]
# sT1:  {~b | ~c, a | b, d | ~c}
# costl:  [-1, 0]
# sT1:  {~b | ~c, a | b}
# costl:  [-1, 0, 1]
# sT1:  {~b | ~c, ~a | ~e, ~a}
# costl:  [-1, 0, 1, 0]
# sT1:  {~b | ~c, ~a | ~e, ~a}
# costl:  [-1, 0, 1, 0, 0]
# dict3:  {b: [True, -1], c: [False, 0], d: [True, 1], a: [True, 0], e: [True, 0]}
# costVltf:  1
# expon.pdf(costVltf) / t:  0.36787944117144233
# rand:  0.7422072629505034
# i0 :  4
# dict1:  {b: True, c: False, d: True, a: True, e: True}
# clF:  {~a | ~e, ~a}
# clT:  {~b | ~c, ~c, d | ~c, a | b}
# sT1:  {d | ~c, a | b}
# costl:  [2]
# sT1:  {~b | ~c, ~c, d | ~c, a | b}
# costl:  [2, 0]
# sT1:  {~b | ~c, ~c, d | ~c, a | b}
# costl:  [2, 0, 0]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [2, 0, 0, -2]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [2, 0, 0, -2, -2]
# dict3:  {b: [False, 2], c: [True, 0], d: [True, 0], a: [True, -2], e: [True, -2]}
# costVltf:  -2
# expon.pdf(costVltf) / t:  0.0
# rand:  0.2236238659130727
# i0 :  5
# dict1:  {b: False, c: True, d: True, a: True, e: True}
# clF:  {~c, ~a | ~e, ~a}
# clT:  {~b | ~c, a | b, d | ~c}
# dict2:  {b: False, c: True, d: True, a: True, e: True}
# vltflst:  [c, 0]
# i0 :  6
# dict1:  {b: False, c: False, d: True, a: True, e: True}
# clF:  {~a | ~e, ~a}
# clT:  {~b | ~c, ~c, d | ~c, a | b}
# dict2:  {b: False, c: False, d: True, a: True, e: True}
# dict2:  {b: False, c: False, d: True, a: False, e: True}
# vltflst:  [a, 0]
# vltflst:  [a, 0, e, 0]
# i0 :  7
# dict1:  {b: False, c: False, d: True, a: False, e: False}
# clF:  {a | b}
# clT:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# sT1:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# costl:  [0]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, ~a}
# costl:  [0, 1]
# sT1:  {~b | ~c, ~a | ~e, ~a}
# costl:  [0, 1, 2]
# sT1:  {~b | ~c, a | b}
# costl:  [0, 1, 2, 3]
# sT1:  {~b | ~c, ~a | ~e, a | b}
# costl:  [0, 1, 2, 3, 2]
# dict3:  {b: [True, 0], c: [False, 1], d: [True, 2], a: [False, 3], e: [True, 2]}
# costVltf:  1
# expon.pdf(costVltf) / t:  0.36787944117144233
# rand:  0.4934472862240914
# i0 :  8
# dict1:  {b: True, c: False, d: True, a: False, e: True}
# clF:  set()
# clT:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# The formula is satisfied
# anw:  {b: True, c: False, d: True, a: False, e: True}
# nsat:  [{b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: False, a: False, e: True}, {b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: True, a: False, e: True}, {b: True, c: False, d: False, a: False, e: True}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: True, a: False, e: True}]
# clauses1:  (~a, ~c, a | b, d | ~c, ~a | ~e, ~b | ~c)
# i0 :  0
# dict1:  {b: False, c: True, d: True, a: False, e: True}
# clF:  {~c, a | b}
# clT:  {~b | ~c, ~a | ~e, d | ~c, ~a}
# dict2:  {b: False, c: True, d: True, a: False, e: True}
# vltflst:  [c, 0]
# i0 :  1
# dict1:  {b: False, c: False, d: True, a: False, e: True}
# clF:  {a | b}
# clT:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# sT1:  {~b | ~c, a | b, d | ~c}
# costl:  [2]
# sT1:  {~b | ~c, ~c, d | ~c, a | b}
# costl:  [2, 1]
# sT1:  {~b | ~c, ~c, d | ~c, a | b}
# costl:  [2, 1, 1]
# sT1:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# costl:  [2, 1, 1, 0]
# sT1:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# costl:  [2, 1, 1, 0, 0]
# dict3:  {b: [True, 2], c: [True, 1], d: [True, 1], a: [True, 0], e: [True, 0]}
# costVltf:  0
# expon.pdf(costVltf) / t:  1.0
# rand:  0.5910060190795191
# i0 :  2
# dict1:  {b: True, c: True, d: True, a: True, e: True}
# clF:  {~b | ~c, ~c, ~a | ~e, ~a}
# clT:  {a | b, d | ~c}
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [-4]
# sT1:  {~a, ~a | ~e, d | ~c, a | b}
# costl:  [-4, -2]
# sT1:  {~a, ~a | ~e, a | b}
# costl:  [-4, -2, -1]
# sT1:  {~a | ~e, a | b}
# costl:  [-4, -2, -1, 0]
# sT1:  {a | b}
# costl:  [-4, -2, -1, 0, 1]
# dict3:  {b: [False, -4], c: [False, -2], d: [True, -1], a: [False, 0], e: [False, 1]}
# costVltf:  -4
# expon.pdf(costVltf) / t:  0.0
# rand:  0.7869083363046369
# i0 :  3
# dict1:  {b: False, c: False, d: True, a: False, e: False}
# clF:  {a | b}
# clT:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# sT1:  {~b | ~c, ~a | ~e, ~a}
# costl:  [2]
# sT1:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# costl:  [2, 0]
# sT1:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# costl:  [2, 0, 0]
# sT1:  {~b | ~c, ~c, d | ~c, a | b}
# costl:  [2, 0, 0, 1]
# sT1:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# costl:  [2, 0, 0, 1, 0]
# dict3:  {b: [True, 2], c: [True, 0], d: [False, 0], a: [False, 1], e: [True, 0]}
# costVltf:  0
# expon.pdf(costVltf) / t:  1.0
# rand:  0.4132223907542285
# i0 :  4
# dict1:  {b: True, c: True, d: False, a: False, e: True}
# clF:  {~c, ~b | ~c, d | ~c}
# clT:  {~a, ~a | ~e, a | b}
# sT1:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# costl:  [-2]
# sT1:  {~b | ~c, ~a | ~e, a | b}
# costl:  [-2, 0]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b}
# costl:  [-2, 0, -1]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, ~a}
# costl:  [-2, 0, -1, -1]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, ~a}
# costl:  [-2, 0, -1, -1, -1]
# dict3:  {b: [True, -2], c: [False, 0], d: [False, -1], a: [True, -1], e: [False, -1]}
# costVltf:  -1
# expon.pdf(costVltf) / t:  0.0
# rand:  0.5106336102257013
# i0 :  5
# dict1:  {b: True, c: False, d: False, a: True, e: False}
# clF:  {~a}
# clT:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# dict2:  {b: True, c: False, d: False, a: True, e: False}
# vltflst:  [a, 0]
# i0 :  6
# dict1:  {b: True, c: False, d: False, a: False, e: False}
# clF:  set()
# clT:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# The formula is satisfied
# anw:  {b: True, c: False, d: False, a: False, e: False}
# nsat:  [{b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: False, a: False, e: True}, {b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: True, a: False, e: True}, {b: True, c: False, d: False, a: False, e: True}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: True, a: False, e: True}, {b: True, c: False, d: False, a: False, e: False}]
# clauses1:  (~a, ~c, a | b, d | ~c, ~a | ~e, ~b | ~c)
# i0 :  0
# dict1:  {b: True, c: True, d: True, a: False, e: True}
# clF:  {~c, ~b | ~c}
# clT:  {~a | ~e, a | b, ~a, d | ~c}
# dict2:  {b: True, c: True, d: True, a: False, e: True}
# vltflst:  [c, 0]
# i0 :  1
# dict1:  {b: True, c: False, d: True, a: False, e: True}
# clF:  set()
# clT:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# The formula is satisfied
# anw:  {b: True, c: False, d: True, a: False, e: True}
# nsat:  [{b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: False, a: False, e: True}, {b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: True, a: False, e: True}, {b: True, c: False, d: False, a: False, e: True}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: True, a: False, e: True}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: True, a: False, e: True}]
# clauses1:  (~a, ~c, a | b, d | ~c, ~a | ~e, ~b | ~c)
# i0 :  0
# dict1:  {b: True, c: True, d: False, a: True, e: False}
# clF:  {~c, ~b | ~c, d | ~c, ~a}
# clT:  {~a | ~e, a | b}
# dict2:  {b: True, c: True, d: False, a: True, e: False}
# dict2:  {b: True, c: False, d: False, a: True, e: False}
# vltflst:  [b, 0]
# vltflst:  [b, 0, c, 0]
# i0 :  1
# dict1:  {b: False, c: False, d: False, a: True, e: False}
# clF:  {~a}
# clT:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# sT1:  {~b | ~c, ~a | ~e, ~a}
# costl:  [2]
# sT1:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# costl:  [2, 0]
# sT1:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# costl:  [2, 0, 0]
# sT1:  {~b | ~c, ~c, d | ~c, a | b}
# costl:  [2, 0, 0, 1]
# sT1:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# costl:  [2, 0, 0, 1, 0]
# dict3:  {b: [True, 2], c: [True, 0], d: [False, 0], a: [False, 1], e: [True, 0]}
# costVltf:  1
# expon.pdf(costVltf) / t:  0.36787944117144233
# rand:  0.8488461975127648
# i0 :  2
# dict1:  {b: True, c: True, d: False, a: False, e: True}
# clF:  {~c, ~b | ~c, d | ~c}
# clT:  {~a, ~a | ~e, a | b}
# dict2:  {b: True, c: True, d: False, a: False, e: True}
# vltflst:  [c, 0]
# i0 :  3
# dict1:  {b: True, c: False, d: False, a: False, e: True}
# clF:  set()
# clT:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# The formula is satisfied
# anw:  {b: True, c: False, d: False, a: False, e: True}
# nsat:  [{b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: False, a: False, e: True}, {b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: True, a: False, e: True}, {b: True, c: False, d: False, a: False, e: True}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: True, a: False, e: True}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: True, a: False, e: True}, {b: True, c: False, d: False, a: False, e: True}]
# clauses1:  (~a, ~c, a | b, d | ~c, ~a | ~e, ~b | ~c)
# i0 :  0
# dict1:  {b: False, c: True, d: False, a: True, e: False}
# clF:  {~c, d | ~c, ~a}
# clT:  {~b | ~c, ~a | ~e, a | b}
# dict2:  {b: False, c: True, d: False, a: True, e: False}
# dict2:  {b: False, c: False, d: False, a: True, e: False}
# vltflst:  [c, 0]
# vltflst:  [c, 0, d, 0]
# i0 :  1
# dict1:  {b: False, c: False, d: True, a: True, e: False}
# clF:  {~a}
# clT:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# dict2:  {b: False, c: False, d: True, a: True, e: False}
# vltflst:  [a, 0]
# i0 :  2
# dict1:  {b: False, c: False, d: True, a: False, e: False}
# clF:  {a | b}
# clT:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# dict2:  {b: False, c: False, d: True, a: False, e: False}
# dict2:  {b: False, c: False, d: True, a: True, e: False}
# vltflst:  [b, 0]
# vltflst:  [b, 0, a, 0]
# i0 :  3
# dict1:  {b: True, c: False, d: True, a: True, e: False}
# clF:  {~a}
# clT:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# dict2:  {b: True, c: False, d: True, a: True, e: False}
# vltflst:  [a, 0]
# i0 :  4
# dict1:  {b: True, c: False, d: True, a: False, e: False}
# clF:  set()
# clT:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# The formula is satisfied
# anw:  {b: True, c: False, d: True, a: False, e: False}
# nsat:  [{b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: False, a: False, e: True}, {b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: True, a: False, e: True}, {b: True, c: False, d: False, a: False, e: True}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: True, a: False, e: True}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: True, a: False, e: True}, {b: True, c: False, d: False, a: False, e: True}, {b: True, c: False, d: True, a: False, e: False}]
# clauses1:  (~a, ~c, a | b, d | ~c, ~a | ~e, ~b | ~c)
# i0 :  0
# dict1:  {b: True, c: False, d: False, a: False, e: True}
# clF:  set()
# clT:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# The formula is satisfied
# anw:  {b: True, c: False, d: False, a: False, e: True}
# nsat:  [{b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: False, a: False, e: True}, {b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: True, a: False, e: True}, {b: True, c: False, d: False, a: False, e: True}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: True, a: False, e: True}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: True, a: False, e: True}, {b: True, c: False, d: False, a: False, e: True}, {b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: False, a: False, e: True}]
# clauses1:  (~a, ~c, a | b, d | ~c, ~a | ~e, ~b | ~c)
# i0 :  0
# dict1:  {b: True, c: False, d: True, a: False, e: True}
# clF:  set()
# clT:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# The formula is satisfied
# anw:  {b: True, c: False, d: True, a: False, e: True}
# nsat:  [{b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: False, a: False, e: True}, {b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: True, a: False, e: True}, {b: True, c: False, d: False, a: False, e: True}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: True, a: False, e: True}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: True, a: False, e: True}, {b: True, c: False, d: False, a: False, e: True}, {b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: False, a: False, e: True}, {b: True, c: False, d: True, a: False, e: True}]
# clauses1:  (~a, ~c, a | b, d | ~c, ~a | ~e, ~b | ~c)
# i0 :  0
# dict1:  {b: True, c: True, d: True, a: True, e: True}
# clF:  {~b | ~c, ~c, ~a | ~e, ~a}
# clT:  {a | b, d | ~c}
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b}
# costl:  [-2]
# sT1:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# costl:  [-2, -3]
# sT1:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# costl:  [-2, -3, -3]
# sT1:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# costl:  [-2, -3, -3, -3]
# sT1:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# costl:  [-2, -3, -3, -3, -3]
# dict3:  {b: [True, -2], c: [True, -3], d: [True, -3], a: [True, -3], e: [False, -3]}
# costVltf:  -3
# expon.pdf(costVltf) / t:  0.0
# rand:  0.05998554697222436
# i0 :  1
# dict1:  {b: True, c: True, d: True, a: True, e: False}
# clF:  {~c, ~b | ~c, ~a}
# clT:  {~a | ~e, d | ~c, a | b}
# dict2:  {b: True, c: True, d: True, a: True, e: False}
# vltflst:  [c, 0]
# i0 :  2
# dict1:  {b: True, c: False, d: True, a: True, e: False}
# clF:  {~a}
# clT:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# sT1:  {~b | ~c, ~c, d | ~c, a | b}
# costl:  [1]
# sT1:  {~b | ~c, a | b}
# costl:  [1, 3]
# sT1:  {~b | ~c, a | b, d | ~c}
# costl:  [1, 3, 2]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, ~a}
# costl:  [1, 3, 2, 1]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, ~a}
# costl:  [1, 3, 2, 1, 1]
# dict3:  {b: [True, 1], c: [False, 3], d: [False, 2], a: [True, 1], e: [True, 1]}
# costVltf:  1
# expon.pdf(costVltf) / t:  0.36787944117144233
# rand:  0.2445938425666393
# i0 :  3
# dict1:  {b: True, c: False, d: False, a: True, e: True}
# clF:  {~a | ~e, ~a}
# clT:  {~b | ~c, ~c, d | ~c, a | b}
# dict2:  {b: True, c: False, d: False, a: True, e: True}
# vltflst:  [a, 0]
# i0 :  4
# dict1:  {b: True, c: False, d: False, a: False, e: True}
# clF:  set()
# clT:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# The formula is satisfied
# anw:  {b: True, c: False, d: False, a: False, e: True}
# nsat:  [{b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: False, a: False, e: True}, {b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: True, a: False, e: True}, {b: True, c: False, d: False, a: False, e: True}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: True, a: False, e: True}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: True, a: False, e: True}, {b: True, c: False, d: False, a: False, e: True}, {b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: False, a: False, e: True}, {b: True, c: False, d: True, a: False, e: True}, {b: True, c: False, d: False, a: False, e: True}]
# clauses1:  (~a, ~c, a | b, d | ~c, ~a | ~e, ~b | ~c)
# i0 :  0
# dict1:  {b: True, c: False, d: False, a: True, e: False}
# clF:  {~a}
# clT:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# sT1:  {~b | ~c, a | b}
# costl:  [3]
# sT1:  {~b | ~c, ~c, d | ~c, a | b}
# costl:  [3, 1]
# sT1:  {~b | ~c, ~c, d | ~c, a | b}
# costl:  [3, 1, 1]
# sT1:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# costl:  [3, 1, 1, 0]
# sT1:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# costl:  [3, 1, 1, 0, 0]
# dict3:  {b: [True, 3], c: [True, 1], d: [False, 1], a: [True, 0], e: [True, 0]}
# costVltf:  1
# expon.pdf(costVltf) / t:  0.36787944117144233
# rand:  0.4297837453154624
# i0 :  1
# dict1:  {b: True, c: True, d: False, a: True, e: True}
# clF:  {~b | ~c, ~c, ~a, ~a | ~e, d | ~c}
# clT:  {a | b}
# sT1:  {~b | ~c, ~a | ~e, d | ~c, ~a}
# costl:  [-3]
# sT1:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# costl:  [-3, -4]
# sT1:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# costl:  [-3, -4, -4]
# sT1:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# costl:  [-3, -4, -4, -4]
# sT1:  {~b | ~c, ~c, d | ~c, a | b}
# costl:  [-3, -4, -4, -4, -3]
# dict3:  {b: [True, -3], c: [True, -4], d: [True, -4], a: [False, -4], e: [False, -3]}
# costVltf:  -4
# expon.pdf(costVltf) / t:  0.0
# rand:  0.2515165686592711
# i0 :  2
# dict1:  {b: True, c: True, d: True, a: False, e: False}
# clF:  {~c, ~b | ~c}
# clT:  {~a | ~e, a | b, ~a, d | ~c}
# sT1:  {d | ~c, a | b}
# costl:  [2]
# sT1:  {~b | ~c, ~c, d | ~c, a | b}
# costl:  [2, 0]
# sT1:  {~b | ~c, ~c, d | ~c, a | b}
# costl:  [2, 0, 0]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [2, 0, 0, -2]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [2, 0, 0, -2, -2]
# dict3:  {b: [False, 2], c: [True, 0], d: [True, 0], a: [True, -2], e: [True, -2]}
# costVltf:  2
# expon.pdf(costVltf) / t:  0.1353352832366127
# rand:  0.7792516036481258
# i0 :  3
# dict1:  {b: False, c: True, d: True, a: True, e: True}
# clF:  {~c, ~a | ~e, ~a}
# clT:  {~b | ~c, a | b, d | ~c}
# dict2:  {b: False, c: True, d: True, a: True, e: True}
# dict2:  {b: False, c: True, d: True, a: False, e: True}
# vltflst:  [a, 0]
# vltflst:  [a, 0, e, 0]
# i0 :  4
# dict1:  {b: False, c: True, d: True, a: False, e: False}
# clF:  {~c, a | b}
# clT:  {~b | ~c, ~a | ~e, d | ~c, ~a}
# dict2:  {b: False, c: True, d: True, a: False, e: False}
# dict2:  {b: False, c: True, d: True, a: True, e: False}
# vltflst:  [b, 0]
# vltflst:  [b, 0, a, 0]
# i0 :  5
# dict1:  {b: True, c: True, d: True, a: True, e: False}
# clF:  {~c, ~b | ~c, ~a}
# clT:  {~a | ~e, d | ~c, a | b}
# sT1:  {d | ~c, a | b}
# costl:  [1]
# sT1:  {~b | ~c, ~c, d | ~c, a | b}
# costl:  [1, -1]
# sT1:  {~b | ~c, ~c, d | ~c, a | b}
# costl:  [1, -1, -1]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [1, -1, -1, -3]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [1, -1, -1, -3, -3]
# dict3:  {b: [False, 1], c: [True, -1], d: [True, -1], a: [True, -3], e: [True, -3]}
# costVltf:  -3
# expon.pdf(costVltf) / t:  0.0
# rand:  0.883581997147381
# i0 :  6
# dict1:  {b: False, c: True, d: True, a: True, e: True}
# clF:  {~c, ~a | ~e, ~a}
# clT:  {~b | ~c, a | b, d | ~c}
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [-3]
# sT1:  {~a, ~a | ~e, d | ~c, a | b}
# costl:  [-3, -1]
# sT1:  {~a, ~a | ~e, a | b}
# costl:  [-3, -1, 0]
# sT1:  {~a | ~e, a | b}
# costl:  [-3, -1, 0, 1]
# sT1:  {a | b}
# costl:  [-3, -1, 0, 1, 2]
# dict3:  {b: [False, -3], c: [False, -1], d: [True, 0], a: [False, 1], e: [False, 2]}
# costVltf:  1
# expon.pdf(costVltf) / t:  0.36787944117144233
# rand:  0.13099590740326406
# i0 :  7
# dict1:  {b: False, c: False, d: True, a: False, e: False}
# clF:  {a | b}
# clT:  {~b | ~c, ~a | ~e, ~c, ~a, d | ~c}
# sT1:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# costl:  [0]
# sT1:  {~b | ~c, ~a | ~e, a | b}
# costl:  [0, 2]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b}
# costl:  [0, 2, 1]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, ~a}
# costl:  [0, 2, 1, 1]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, ~a}
# costl:  [0, 2, 1, 1, 1]
# dict3:  {b: [True, 0], c: [False, 2], d: [False, 1], a: [True, 1], e: [False, 1]}
# costVltf:  1
# expon.pdf(costVltf) / t:  0.36787944117144233
# rand:  0.2729931274254861
# i0 :  8
# dict1:  {b: True, c: False, d: False, a: True, e: False}
# clF:  {~a}
# clT:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# sT1:  {a | b}
# costl:  [4]
# sT1:  {~b | ~c, ~c, d | ~c, a | b}
# costl:  [4, 1]
# sT1:  {~b | ~c, ~c, d | ~c, a | b}
# costl:  [4, 1, 1]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [4, 1, 1, -1]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# costl:  [4, 1, 1, -1, -1]
# dict3:  {b: [False, 4], c: [True, 1], d: [False, 1], a: [True, -1], e: [True, -1]}
# costVltf:  1
# expon.pdf(costVltf) / t:  0.36787944117144233
# rand:  0.340892405964225
# i0 :  9
# dict1:  {b: False, c: True, d: False, a: True, e: True}
# clF:  {~c, ~a | ~e, d | ~c, ~a}
# clT:  {~b | ~c, a | b}
# sT1:  {~b | ~c, ~c, d | ~c, a | b}
# costl:  [-2]
# sT1:  {~b | ~c, a | b}
# costl:  [-2, 0]
# sT1:  {~b | ~c, a | b, d | ~c}
# costl:  [-2, 0, -1]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, ~a}
# costl:  [-2, 0, -1, -2]
# sT1:  {~b | ~c, ~a | ~e, d | ~c, ~a}
# costl:  [-2, 0, -1, -2, -2]
# dict3:  {b: [True, -2], c: [False, 0], d: [False, -1], a: [True, -2], e: [True, -2]}
# costVltf:  -2
# expon.pdf(costVltf) / t:  0.0
# rand:  0.4892044230603255
# i0 :  10
# dict1:  {b: True, c: False, d: False, a: True, e: True}
# clF:  {~a | ~e, ~a}
# clT:  {~b | ~c, ~c, d | ~c, a | b}
# dict2:  {b: True, c: False, d: False, a: True, e: True}
# dict2:  {b: True, c: False, d: False, a: False, e: True}
# vltflst:  [a, 0]
# vltflst:  [a, 0, e, 0]
# i0 :  11
# dict1:  {b: True, c: False, d: False, a: False, e: False}
# clF:  set()
# clT:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# The formula is satisfied
# anw:  {b: True, c: False, d: False, a: False, e: False}
# nsat:  [{b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: False, a: False, e: True}, {b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: True, a: False, e: True}, {b: True, c: False, d: False, a: False, e: True}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: True, a: False, e: True}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: True, a: False, e: True}, {b: True, c: False, d: False, a: False, e: True}, {b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: False, a: False, e: True}, {b: True, c: False, d: True, a: False, e: True}, {b: True, c: False, d: False, a: False, e: True}, {b: True, c: False, d: False, a: False, e: False}]
# clauses1:  (~a, ~c, a | b, d | ~c, ~a | ~e, ~b | ~c)
# i0 :  0
# dict1:  {b: True, c: False, d: True, a: True, e: False}
# clF:  {~a}
# clT:  {~b | ~c, ~a | ~e, a | b, ~c, d | ~c}
# dict2:  {b: True, c: False, d: True, a: True, e: False}
# vltflst:  [a, 0]
# i0 :  1
# dict1:  {b: True, c: False, d: True, a: False, e: False}
# clF:  set()
# clT:  {~b | ~c, ~a | ~e, d | ~c, a | b, ~c, ~a}
# The formula is satisfied
# anw:  {b: True, c: False, d: True, a: False, e: False}
# nsat:  [{b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: False, a: False, e: True}, {b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: True, a: False, e: True}, {b: True, c: False, d: False, a: False, e: True}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: True, a: False, e: True}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: True, a: False, e: True}, {b: True, c: False, d: False, a: False, e: True}, {b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: False, a: False, e: True}, {b: True, c: False, d: True, a: False, e: True}, {b: True, c: False, d: False, a: False, e: True}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: True, a: False, e: False}]
# nsat:  [{b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: False, a: False, e: True}, {b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: True, a: False, e: True}, {b: True, c: False, d: False, a: False, e: True}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: True, a: False, e: True}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: True, a: False, e: True}, {b: True, c: False, d: False, a: False, e: True}, {b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: False, a: False, e: True}, {b: True, c: False, d: True, a: False, e: True}, {b: True, c: False, d: False, a: False, e: True}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: True, a: False, e: False}]
# nsatSet:  [{b: True, c: False, d: True, a: False, e: False}, {b: True, c: False, d: False, a: False, e: True}, {b: True, c: False, d: False, a: False, e: False}, {b: True, c: False, d: True, a: False, e: True}]
# pickvarF:  [b, c, d, a, e]
# x:  b
# sat:  {b: True, c: False, d: True, a: False, e: False}
# x1:  True
# sat:  {b: True, c: False, d: False, a: False, e: True}
# x1:  True
# sat:  {b: True, c: False, d: False, a: False, e: False}
# x1:  True
# sat:  {b: True, c: False, d: True, a: False, e: True}
# x1:  True
# nt:  4.0
# mxt: [1.0]
# x:  c
# sat:  {b: True, c: False, d: True, a: False, e: False}
# x1:  False
# sat:  {b: True, c: False, d: False, a: False, e: True}
# x1:  False
# sat:  {b: True, c: False, d: False, a: False, e: False}
# x1:  False
# sat:  {b: True, c: False, d: True, a: False, e: True}
# x1:  False
# mxf: [1.0, 1.0]
# x:  d
# sat:  {b: True, c: False, d: True, a: False, e: False}
# x1:  True
# sat:  {b: True, c: False, d: False, a: False, e: True}
# x1:  False
# sat:  {b: True, c: False, d: False, a: False, e: False}
# x1:  False
# sat:  {b: True, c: False, d: True, a: False, e: True}
# x1:  True
# mxf: [1.0, 1.0, 2.0]
# x:  a
# sat:  {b: True, c: False, d: True, a: False, e: False}
# x1:  False
# sat:  {b: True, c: False, d: False, a: False, e: True}
# x1:  False
# sat:  {b: True, c: False, d: False, a: False, e: False}
# x1:  False
# sat:  {b: True, c: False, d: True, a: False, e: True}
# x1:  False
# mxf: [1.0, 1.0, 2.0, 1.0]
# x:  e
# sat:  {b: True, c: False, d: True, a: False, e: False}
# x1:  False
# sat:  {b: True, c: False, d: False, a: False, e: True}
# x1:  True
# sat:  {b: True, c: False, d: False, a: False, e: False}
# x1:  False
# sat:  {b: True, c: False, d: True, a: False, e: True}
# x1:  True
# mxf: [1.0, 1.0, 2.0, 1.0, 2.0]
# result: 4.0

# %% [markdown]
# list of websites that I used:
#
# https://docs.sympy.org/latest/modules/logic.html
#
# https://docs.sympy.org/latest/modules/logic.html#simplification-and-equivalence-testing
#
# https://docs.sympy.org/latest/modules/parsing.html
#
# https://docs.sympy.org/latest/modules/core.html
#
# https://docs.python.org/3.7/tutorial/errors.html#tut-handling
#
# https://www.w3schools.com/python/python_howto_remove_duplicates.asp
